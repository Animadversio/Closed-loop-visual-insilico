# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Model export to Thomas

# %%
import os
from os.path import join
import torch as th
import torch
from sklearn.decomposition import PCA
from sklearn.random_projection import SparseRandomProjection
import pickle as pkl
import numpy as np
import matplotlib.pyplot as plt
from os.path import join
import sys
sys.path.append("/n/home12/binxuwang/Github/Closed-loop-visual-insilico")
from core.data_utils import load_from_hdf5, load_neural_data, load_neural_trial_resp_tensor, create_response_tensor, parse_image_fullpaths
from core.model_load_utils import load_model_transform, MODEL_LAYER_FILTERS, LAYER_ABBREVIATION_MAPS
from neural_regress.feature_reduction_lib import FEATURE_REDUCTION_DEFAULTS, LAYER_TRANSFORM_FILTERS
from neural_regress.regress_lib import record_features, perform_regression_sweeplayer, perform_regression_sweeplayer_RidgeCV
from neural_regress.regress_lib import sweep_regressors, transform_features2Xdict_new, transform_features2Xdict, RidgeCV, apply_feature_transforms
from neural_regress.regress_eval_lib import format_result_df, plot_result_df_per_layer, construct_result_df_masked, \
    compute_pred_dict_D2_per_unit, format_result_df_tuple_index
from neural_regress.sklearn_torchify_lib import SRP_torch, PCA_torch, LinearRegression_torch
from neural_regress.sklearn_torchify_lib import LinearLayer_from_sklearn, PCA_torch, SRP_torch

# %%
import yaml
import datetime
def create_accentuation_config(
    subject_id, 
    modelname, 
    unit_id, 
    regressor_name, 
    layername, 
    exportdir, 
    export_readout_path, 
    export_Xtransform_JIT_path, 
    export_meta_path, 
    date=None,
    template_path=None, 
):
    """
    Create an accentuation configuration by filling in a template with specific values.
    
    Args:
        template_path: Path to the YAML template file
        subject_id: Subject ID for the experiment
        modelname: Name of the model
        unit_id: ID of the unit to process
        regressor_name: Name of the regression method
        layername: Name of the layer
        exportdir: Directory to export results
        export_readout_path: Path to the exported readout
        export_Xtransform_JIT_path: Path to the exported transform JIT script
        export_meta_path: Path to the exported metadata
        
    Returns:
        dict: Loaded YAML configuration
    """
    import datetime
    import yaml
    if template_path is None:
        template_path = "/n/home12/binxuwang/Github/Closed-loop-visual-insilico/notebooks/accentuation_template.yaml"
    with open(template_path, "r") as f:
        content = f.read()
    
    content = content.replace("{{subject_id}}", subject_id)
    content = content.replace("{{model_name}}", modelname)
    content = content.replace('"{{unit_ids}}"', str([unit_id]))
    content = content.replace("{{fit_method_name}}", regressor_name)
    content = content.replace("{{layer_name}}", layername)
    content = content.replace("{{outputdir}}", exportdir)
    content = content.replace("{{readout_path}}", export_readout_path)
    content = content.replace("{{xtransform_path}}", export_Xtransform_JIT_path)
    content = content.replace("{{meta_path}}", export_meta_path)
    if date is None:
        content = content.replace("{{date}}", datetime.datetime.now().strftime("%d-%m-%Y"))
    else:
        content = content.replace("{{date}}", date)
    
    return content, yaml.safe_load(content)


def save_and_verify_config(content, output_yaml_path, config=None):
    """
    Save the configuration to a file and verify it loads correctly.
    
    Args:
        content: YAML content as string
        config: Configuration dictionary
        exportdir: Directory to export the configuration
        subject_id: Subject ID for the experiment
        modelname: Name of the model
        unit_id: ID of the unit to process
        
    Returns:
        str: Path to the saved configuration file
    """
    with open(output_yaml_path, "w") as f:
        f.write(content)
    print(f"Configuration saved to {output_yaml_path}")
    
    # Verify that it loads correctly
    try:
        loaded_config = yaml.safe_load(open(output_yaml_path, "r"))
        print("Configuration loaded successfully")
        # check it's the same as config
        if config is not None:
            assert loaded_config == config, "Loaded configuration differs from original config"
            print("Loaded configuration matches the original config")
    except Exception as e:
        print(f"Error loading configuration: {e}")
    
    return output_yaml_path

# %%
model_root = "/n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_models/"
subject_id = "red_20250428-20240429"

raw_model_output_dir = join(model_root, subject_id, "model_outputs")
exportdir = f"/n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/{subject_id}"
os.makedirs(exportdir, exist_ok=True)
yaml_exportdir = f"/n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/accentuation_configs/{subject_id}"
os.makedirs(yaml_exportdir, exist_ok=True)

# %%
dataroot = r"/n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Ephys_Data"
data_path = join(dataroot, "red_20250428-20240429_vvs-encodingstimuli_z1_rw100-400.h5")
data = load_from_hdf5(data_path)

encoding_stim_dir = r"/n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Stimuli/encodingstimuli_apr2025"
data_dict = {}
data_dict['image_fps'] = parse_image_fullpaths(data['repavg']["stimulus_name"], [encoding_stim_dir], arbitrary_format=True)
data_dict['resp_mat'] = data['repavg']["response_peak"]
data_dict['resp_temp_mat'] = data['repavg']["response_temporal"]
data_dict['reliability'] = data['neuron_metadata']["reliability"]
data_dict['ncsnr'] = data['neuron_metadata']["ncsnr"]
data_dict['brain_area'] = data['neuron_metadata']["brain_area"]
data_dict['stim_pos'] = data['stimulus_meta']['xy_deg']
data_dict['stim_size'] = data["stimulus_meta"]["size_px"]
# Out:
# All stimulus files were found

# %%
resp_mat = data_dict['resp_mat']
ncsnr = data_dict['ncsnr']
reliability = data_dict["reliability"]
# save resp statistics 
mean_resp = resp_mat.mean(0)
std_resp = resp_mat.std(0)
q05_resp = np.percentile(resp_mat, 5, axis=0)
q95_resp = np.percentile(resp_mat, 95, axis=0)
min_resp = resp_mat.min(0)
max_resp = resp_mat.max(0)
resp_stats = {
    "resp_mat": resp_mat,
    "mean_resp": mean_resp,
    "std_resp": std_resp,
    "q05_resp": q05_resp,
    "q95_resp": q95_resp,
    "min_resp": min_resp,
    "max_resp": max_resp,
}
np.savez(join(exportdir, f"{subject_id}_resp_stats.npz"), **resp_stats)

# %%
# Get indices of top 5 most reliable neurons
topk_reliable_chan_idx = np.argsort(data_dict['reliability'])[-5:][::-1]
topk_reliability = data_dict['reliability'][topk_reliable_chan_idx]
print("Most reliable channels")
print(topk_reliability)
print(topk_reliable_chan_idx)
# Out:
# Most reliable channels
# [0.8390227  0.82361527 0.80060784 0.78369492 0.77112247]
# [15  9  0 19  2]

# %%
model_names = [
    "dinov2_vitb14_reg",
    "clipag_vitb32",
    "siglip2_vitb16",
    "radio_v2.5-b",
    "resnet50_robust",
    "resnet50_clip",
    "resnet50_dino",
    "resnet50",
    "regnety_640",
    "AlexNet_training_seed_01",
    # "ReAlnet01",
]
for modelname in [
    "resnet50_robust",
    "resnet50_clip",
    "resnet50_dino",
    "resnet50",
    "regnety_640",
    "AlexNet_training_seed_01",
]:
    Xtransform_path = join(raw_model_output_dir, f"{subject_id}_{modelname}_sweep_regressors_layers_Xtfmer_RidgeCV.pkl")
    # red_20250428-20240429_resnet50_robust_sweep_regressors_layers_Xtfmer_RidgeCV.pkl
    readout_path = join(raw_model_output_dir, f"{subject_id}_{modelname}_sweep_regressors_layers_fitmodels_RidgeCV.pth")
    meta_path = join(raw_model_output_dir, f"{subject_id}_{modelname}_sweep_regressors_layers_pred_meta.pkl")
    fit_models_lyrswp_RidgeCV = th.load(readout_path)
    # Xtfmer_lyrswp_RidgeCV = th.load(Xtransform_path)
    Xtfmer_lyrswp_RidgeCV = pkl.load(open(Xtransform_path, "rb"))
    pred_data = pkl.load(open(meta_path, "rb"))
    pred_dict = pred_data["pred_dict"]
    D2_per_unit_train_dict = pred_data["D2_per_unit_train_dict"]
    D2_per_unit_test_dict = pred_data["D2_per_unit_test_dict"]
    for unit_id in topk_reliable_chan_idx:
        single_chan_result_df = construct_result_df_masked(D2_per_unit_train_dict, D2_per_unit_test_dict, mask=unit_id)
        single_chan_result_df = format_result_df_tuple_index(single_chan_result_df, )
        # Filter out 'srp' dimension reduction and get the row with the best test score
        best_reg_row = single_chan_result_df.query("dimred != 'srp'").sort_values('test_score', ascending=False).iloc[0]
        print("Best config ")
        best_row = single_chan_result_df.query("dimred != 'srp'").sort_values('test_score', ascending=False).iloc[0]
        print(f"Best config - layer: {best_row['layer']}, dimred: {best_row['dimred']}, regressor: {best_row['regressor']}, "+\
              f"train_score: {best_row['train_score']:.3f}, test_score: {best_row['test_score']:.3f}")
        layername = best_row['layer']
        dimred_str = best_row['dimred']
        regressor_name = best_row['regressor']
        # raise Exception

        export_Xtransform_path = join(exportdir, f"{subject_id}_{modelname}_Ch{unit_id:02d}_Xtfmer_{layername}_{dimred_str}_{regressor_name}.pth")
        export_Xtransform_JIT_path = export_Xtransform_path.replace('.pth', '_JITscript.pt')
        export_meta_path = join(exportdir, f"{subject_id}_{modelname}_Ch{unit_id:02d}_meta_{layername}_{dimred_str}_{regressor_name}.pkl")
        export_readout_path = join(exportdir, f"{subject_id}_{modelname}_Ch{unit_id:02d}_readout_{layername}_{dimred_str}_{regressor_name}.pth")
        key = ((layername, dimred_str), regressor_name)
        
        regressor = fit_models_lyrswp_RidgeCV[key]
        Xtfmer = Xtfmer_lyrswp_RidgeCV[key[0]]
        pred_rsp = pred_data["pred_dict"][key]
        D2_per_unit_test = pred_data["D2_per_unit_test_dict"][key]
        D2_per_unit_train = pred_data["D2_per_unit_train_dict"][key]
        readout = LinearLayer_from_sklearn(regressor)
        th.save(readout, export_readout_path)
        if isinstance(Xtfmer, PCA):
            Xtfmer = PCA_torch(Xtfmer)
        elif isinstance(Xtfmer, SparseRandomProjection):
            Xtfmer = SRP_torch(Xtfmer)
        th.save(Xtfmer, export_Xtransform_path)
        Xtfmer_script = torch.jit.script(Xtfmer)
        Xtfmer_script.save(export_Xtransform_JIT_path)
        th.save({
            "reliability": reliability,
            "ncsnr": ncsnr,
            "D2_per_unit_test": D2_per_unit_test,
            "D2_per_unit_train": D2_per_unit_train,
            **resp_stats
        }, export_meta_path)
        print(f"Saved {export_readout_path}")
        print(f"Saved {export_Xtransform_path}")
        print(f"JIT script saved to {export_Xtransform_JIT_path}")
        print(f"Saved {export_meta_path}")
        # export yaml to somewhere        
        content, config = create_accentuation_config(
            subject_id=subject_id,
            modelname=modelname,
            unit_id=unit_id,
            regressor_name=regressor_name,
            layername=layername,
            exportdir=exportdir,
            export_readout_path=export_readout_path,
            export_Xtransform_JIT_path=export_Xtransform_JIT_path,
            export_meta_path=export_meta_path
        )
        output_yaml_path = f"{yaml_exportdir}/{subject_id}_{modelname}_Ch{unit_id}_accentuation_config.yaml"
        save_and_verify_config(content, output_yaml_path, config)
raise Exception
# Out:
# Best config
# Best config - layer: .layer4.Bottleneck2, dimred: pca750, regressor: RidgeCV, train_score: 0.896, test_score: 0.885
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_robust_Ch15_readout_.layer4.Bottleneck2_pca750_RidgeCV.pth
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_robust_Ch15_Xtfmer_.layer4.Bottleneck2_pca750_RidgeCV.pth
# JIT script saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_robust_Ch15_Xtfmer_.layer4.Bottleneck2_pca750_RidgeCV_JITscript.pt
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_robust_Ch15_meta_.layer4.Bottleneck2_pca750_RidgeCV.pkl
# Configuration saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/accentuation_configs/red_20250428-20240429/red_20250428-20240429_resnet50_robust_Ch15_accentuation_config.yaml
# Configuration loaded successfully
# Loaded configuration matches the original config
# Best config
# Best config - layer: .layer4.Bottleneck0, dimred: pca750, regressor: RidgeCV, train_score: 0.956, test_score: 0.942
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_robust_Ch09_readout_.layer4.Bottleneck0_pca750_RidgeCV.pth
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_robust_Ch09_Xtfmer_.layer4.Bottleneck0_pca750_RidgeCV.pth
# JIT script saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_robust_Ch09_Xtfmer_.layer4.Bottleneck0_pca750_RidgeCV_JITscript.pt
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_robust_Ch09_meta_.layer4.Bottleneck0_pca750_RidgeCV.pkl
# Configuration saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/accentuation_configs/red_20250428-20240429/red_20250428-20240429_resnet50_robust_Ch9_accentuation_config.yaml
# Configuration loaded successfully
# Loaded configuration matches the original config
# Best config
# Best config - layer: .layer3.Bottleneck5, dimred: pca750, regressor: RidgeCV, train_score: 0.847, test_score: 0.847
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_robust_Ch00_readout_.layer3.Bottleneck5_pca750_RidgeCV.pth
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_robust_Ch00_Xtfmer_.layer3.Bottleneck5_pca750_RidgeCV.pth
# JIT script saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_robust_Ch00_Xtfmer_.layer3.Bottleneck5_pca750_RidgeCV_JITscript.pt
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_robust_Ch00_meta_.layer3.Bottleneck5_pca750_RidgeCV.pkl
# Configuration saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/accentuation_configs/red_20250428-20240429/red_20250428-20240429_resnet50_robust_Ch0_accentuation_config.yaml
# Configuration loaded successfully
# Loaded configuration matches the original config
# Best config
# Best config - layer: .layer4.Bottleneck2, dimred: pca750, regressor: RidgeCV, train_score: 0.906, test_score: 0.900
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_robust_Ch19_readout_.layer4.Bottleneck2_pca750_RidgeCV.pth
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_robust_Ch19_Xtfmer_.layer4.Bottleneck2_pca750_RidgeCV.pth
# JIT script saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_robust_Ch19_Xtfmer_.layer4.Bottleneck2_pca750_RidgeCV_JITscript.pt
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_robust_Ch19_meta_.layer4.Bottleneck2_pca750_RidgeCV.pkl
# Configuration saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/accentuation_configs/red_20250428-20240429/red_20250428-20240429_resnet50_robust_Ch19_accentuation_config.yaml
# Configuration loaded successfully
# Loaded configuration matches the original config
# Best config
# Best config - layer: .layer4.Bottleneck2, dimred: pca750, regressor: RidgeCV, train_score: 0.793, test_score: 0.680
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_robust_Ch02_readout_.layer4.Bottleneck2_pca750_RidgeCV.pth
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_robust_Ch02_Xtfmer_.layer4.Bottleneck2_pca750_RidgeCV.pth
# JIT script saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_robust_Ch02_Xtfmer_.layer4.Bottleneck2_pca750_RidgeCV_JITscript.pt
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_robust_Ch02_meta_.layer4.Bottleneck2_pca750_RidgeCV.pkl
# Configuration saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/accentuation_configs/red_20250428-20240429/red_20250428-20240429_resnet50_robust_Ch2_accentuation_config.yaml
# Configuration loaded successfully
# Loaded configuration matches the original config
# Best config
# Best config - layer: .layer4.Bottleneck2, dimred: pca750, regressor: RidgeCV, train_score: 0.907, test_score: 0.881
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_clip_Ch15_readout_.layer4.Bottleneck2_pca750_RidgeCV.pth
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_clip_Ch15_Xtfmer_.layer4.Bottleneck2_pca750_RidgeCV.pth
# JIT script saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_clip_Ch15_Xtfmer_.layer4.Bottleneck2_pca750_RidgeCV_JITscript.pt
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_clip_Ch15_meta_.layer4.Bottleneck2_pca750_RidgeCV.pkl
# Configuration saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/accentuation_configs/red_20250428-20240429/red_20250428-20240429_resnet50_clip_Ch15_accentuation_config.yaml
# Configuration loaded successfully
# Loaded configuration matches the original config
# Best config
# Best config - layer: .layer3.Bottleneck4, dimred: pca750, regressor: RidgeCV, train_score: 0.946, test_score: 0.953
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_clip_Ch09_readout_.layer3.Bottleneck4_pca750_RidgeCV.pth
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_clip_Ch09_Xtfmer_.layer3.Bottleneck4_pca750_RidgeCV.pth
# JIT script saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_clip_Ch09_Xtfmer_.layer3.Bottleneck4_pca750_RidgeCV_JITscript.pt
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_clip_Ch09_meta_.layer3.Bottleneck4_pca750_RidgeCV.pkl
# Configuration saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/accentuation_configs/red_20250428-20240429/red_20250428-20240429_resnet50_clip_Ch9_accentuation_config.yaml
# Configuration loaded successfully
# Loaded configuration matches the original config
# Best config
# Best config - layer: .layer4.Bottleneck2, dimred: pca750, regressor: RidgeCV, train_score: 0.861, test_score: 0.865
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_clip_Ch00_readout_.layer4.Bottleneck2_pca750_RidgeCV.pth
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_clip_Ch00_Xtfmer_.layer4.Bottleneck2_pca750_RidgeCV.pth
# JIT script saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_clip_Ch00_Xtfmer_.layer4.Bottleneck2_pca750_RidgeCV_JITscript.pt
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_clip_Ch00_meta_.layer4.Bottleneck2_pca750_RidgeCV.pkl
# Configuration saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/accentuation_configs/red_20250428-20240429/red_20250428-20240429_resnet50_clip_Ch0_accentuation_config.yaml
# Configuration loaded successfully
# Loaded configuration matches the original config
# Best config
# Best config - layer: .layer3.Bottleneck5, dimred: pca750, regressor: RidgeCV, train_score: 0.916, test_score: 0.927
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_clip_Ch19_readout_.layer3.Bottleneck5_pca750_RidgeCV.pth
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_clip_Ch19_Xtfmer_.layer3.Bottleneck5_pca750_RidgeCV.pth
# JIT script saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_clip_Ch19_Xtfmer_.layer3.Bottleneck5_pca750_RidgeCV_JITscript.pt
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_clip_Ch19_meta_.layer3.Bottleneck5_pca750_RidgeCV.pkl
# Configuration saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/accentuation_configs/red_20250428-20240429/red_20250428-20240429_resnet50_clip_Ch19_accentuation_config.yaml
# Configuration loaded successfully
# Loaded configuration matches the original config
# Best config
# Best config - layer: .layer4.Bottleneck2, dimred: pca750, regressor: RidgeCV, train_score: 0.827, test_score: 0.699
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_clip_Ch02_readout_.layer4.Bottleneck2_pca750_RidgeCV.pth
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_clip_Ch02_Xtfmer_.layer4.Bottleneck2_pca750_RidgeCV.pth
# JIT script saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_clip_Ch02_Xtfmer_.layer4.Bottleneck2_pca750_RidgeCV_JITscript.pt
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_clip_Ch02_meta_.layer4.Bottleneck2_pca750_RidgeCV.pkl
# Configuration saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/accentuation_configs/red_20250428-20240429/red_20250428-20240429_resnet50_clip_Ch2_accentuation_config.yaml
# Configuration loaded successfully
# Loaded configuration matches the original config
# Best config
# Best config - layer: .layer3.Bottleneck5, dimred: pca750, regressor: RidgeCV, train_score: 0.913, test_score: 0.859
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_dino_Ch15_readout_.layer3.Bottleneck5_pca750_RidgeCV.pth
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_dino_Ch15_Xtfmer_.layer3.Bottleneck5_pca750_RidgeCV.pth
# JIT script saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_dino_Ch15_Xtfmer_.layer3.Bottleneck5_pca750_RidgeCV_JITscript.pt
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_dino_Ch15_meta_.layer3.Bottleneck5_pca750_RidgeCV.pkl
# Configuration saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/accentuation_configs/red_20250428-20240429/red_20250428-20240429_resnet50_dino_Ch15_accentuation_config.yaml
# Configuration loaded successfully
# Loaded configuration matches the original config
# Best config
# Best config - layer: .layer4.Bottleneck2, dimred: pca750, regressor: RidgeCV, train_score: 0.951, test_score: 0.942
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_dino_Ch09_readout_.layer4.Bottleneck2_pca750_RidgeCV.pth
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_dino_Ch09_Xtfmer_.layer4.Bottleneck2_pca750_RidgeCV.pth
# JIT script saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_dino_Ch09_Xtfmer_.layer4.Bottleneck2_pca750_RidgeCV_JITscript.pt
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_dino_Ch09_meta_.layer4.Bottleneck2_pca750_RidgeCV.pkl
# Configuration saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/accentuation_configs/red_20250428-20240429/red_20250428-20240429_resnet50_dino_Ch9_accentuation_config.yaml
# Configuration loaded successfully
# Loaded configuration matches the original config
# Best config
# Best config - layer: .layer3.Bottleneck5, dimred: pca750, regressor: RidgeCV, train_score: 0.844, test_score: 0.870
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_dino_Ch00_readout_.layer3.Bottleneck5_pca750_RidgeCV.pth
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_dino_Ch00_Xtfmer_.layer3.Bottleneck5_pca750_RidgeCV.pth
# JIT script saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_dino_Ch00_Xtfmer_.layer3.Bottleneck5_pca750_RidgeCV_JITscript.pt
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_dino_Ch00_meta_.layer3.Bottleneck5_pca750_RidgeCV.pkl
# Configuration saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/accentuation_configs/red_20250428-20240429/red_20250428-20240429_resnet50_dino_Ch0_accentuation_config.yaml
# Configuration loaded successfully
# Loaded configuration matches the original config
# Best config
# Best config - layer: .layer3.Bottleneck5, dimred: pca750, regressor: RidgeCV, train_score: 0.869, test_score: 0.886
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_dino_Ch19_readout_.layer3.Bottleneck5_pca750_RidgeCV.pth
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_dino_Ch19_Xtfmer_.layer3.Bottleneck5_pca750_RidgeCV.pth
# JIT script saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_dino_Ch19_Xtfmer_.layer3.Bottleneck5_pca750_RidgeCV_JITscript.pt
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_dino_Ch19_meta_.layer3.Bottleneck5_pca750_RidgeCV.pkl
# Configuration saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/accentuation_configs/red_20250428-20240429/red_20250428-20240429_resnet50_dino_Ch19_accentuation_config.yaml
# Configuration loaded successfully
# Loaded configuration matches the original config
# Best config
# Best config - layer: .layer3.Bottleneck5, dimred: pca750, regressor: RidgeCV, train_score: 0.840, test_score: 0.675
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_dino_Ch02_readout_.layer3.Bottleneck5_pca750_RidgeCV.pth
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_dino_Ch02_Xtfmer_.layer3.Bottleneck5_pca750_RidgeCV.pth
# JIT script saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_dino_Ch02_Xtfmer_.layer3.Bottleneck5_pca750_RidgeCV_JITscript.pt
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_dino_Ch02_meta_.layer3.Bottleneck5_pca750_RidgeCV.pkl
# Configuration saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/accentuation_configs/red_20250428-20240429/red_20250428-20240429_resnet50_dino_Ch2_accentuation_config.yaml
# Configuration loaded successfully
# Loaded configuration matches the original config
# Best config
# Best config - layer: .layer3.Bottleneck4, dimred: pca750, regressor: RidgeCV, train_score: 0.883, test_score: 0.854
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_Ch15_readout_.layer3.Bottleneck4_pca750_RidgeCV.pth
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_Ch15_Xtfmer_.layer3.Bottleneck4_pca750_RidgeCV.pth
# JIT script saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_Ch15_Xtfmer_.layer3.Bottleneck4_pca750_RidgeCV_JITscript.pt
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_Ch15_meta_.layer3.Bottleneck4_pca750_RidgeCV.pkl
# Configuration saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/accentuation_configs/red_20250428-20240429/red_20250428-20240429_resnet50_Ch15_accentuation_config.yaml
# Configuration loaded successfully
# Loaded configuration matches the original config
# Best config
# Best config - layer: .layer4.Bottleneck0, dimred: pca750, regressor: RidgeCV, train_score: 0.947, test_score: 0.949
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_Ch09_readout_.layer4.Bottleneck0_pca750_RidgeCV.pth
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_Ch09_Xtfmer_.layer4.Bottleneck0_pca750_RidgeCV.pth
# JIT script saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_Ch09_Xtfmer_.layer4.Bottleneck0_pca750_RidgeCV_JITscript.pt
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_Ch09_meta_.layer4.Bottleneck0_pca750_RidgeCV.pkl
# Configuration saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/accentuation_configs/red_20250428-20240429/red_20250428-20240429_resnet50_Ch9_accentuation_config.yaml
# Configuration loaded successfully
# Loaded configuration matches the original config
# Best config
# Best config - layer: .layer3.Bottleneck3, dimred: pca750, regressor: RidgeCV, train_score: 0.833, test_score: 0.850
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_Ch00_readout_.layer3.Bottleneck3_pca750_RidgeCV.pth
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_Ch00_Xtfmer_.layer3.Bottleneck3_pca750_RidgeCV.pth
# JIT script saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_Ch00_Xtfmer_.layer3.Bottleneck3_pca750_RidgeCV_JITscript.pt
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_Ch00_meta_.layer3.Bottleneck3_pca750_RidgeCV.pkl
# Configuration saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/accentuation_configs/red_20250428-20240429/red_20250428-20240429_resnet50_Ch0_accentuation_config.yaml
# Configuration loaded successfully
# Loaded configuration matches the original config
# Best config
# Best config - layer: .layer4.Bottleneck0, dimred: pca750, regressor: RidgeCV, train_score: 0.907, test_score: 0.914
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_Ch19_readout_.layer4.Bottleneck0_pca750_RidgeCV.pth
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_Ch19_Xtfmer_.layer4.Bottleneck0_pca750_RidgeCV.pth
# JIT script saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_Ch19_Xtfmer_.layer4.Bottleneck0_pca750_RidgeCV_JITscript.pt
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_Ch19_meta_.layer4.Bottleneck0_pca750_RidgeCV.pkl
# Configuration saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/accentuation_configs/red_20250428-20240429/red_20250428-20240429_resnet50_Ch19_accentuation_config.yaml
# Configuration loaded successfully
# Loaded configuration matches the original config
# Best config
# Best config - layer: .layer4.Bottleneck0, dimred: pca750, regressor: RidgeCV, train_score: 0.844, test_score: 0.690
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_Ch02_readout_.layer4.Bottleneck0_pca750_RidgeCV.pth
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_Ch02_Xtfmer_.layer4.Bottleneck0_pca750_RidgeCV.pth
# JIT script saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_Ch02_Xtfmer_.layer4.Bottleneck0_pca750_RidgeCV_JITscript.pt
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_Ch02_meta_.layer4.Bottleneck0_pca750_RidgeCV.pkl
# Configuration saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/accentuation_configs/red_20250428-20240429/red_20250428-20240429_resnet50_Ch2_accentuation_config.yaml
# Configuration loaded successfully
# Loaded configuration matches the original config
# Best config
# Best config - layer: .s3.Bottleneckb11, dimred: pca750, regressor: RidgeCV, train_score: 0.917, test_score: 0.891
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_regnety_640_Ch15_readout_.s3.Bottleneckb11_pca750_RidgeCV.pth
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_regnety_640_Ch15_Xtfmer_.s3.Bottleneckb11_pca750_RidgeCV.pth
# JIT script saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_regnety_640_Ch15_Xtfmer_.s3.Bottleneckb11_pca750_RidgeCV_JITscript.pt
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_regnety_640_Ch15_meta_.s3.Bottleneckb11_pca750_RidgeCV.pkl
# Configuration saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/accentuation_configs/red_20250428-20240429/red_20250428-20240429_regnety_640_Ch15_accentuation_config.yaml
# Configuration loaded successfully
# Loaded configuration matches the original config
# Best config
# Best config - layer: .s4.Bottleneckb1, dimred: pca750, regressor: RidgeCV, train_score: 0.953, test_score: 0.941
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_regnety_640_Ch09_readout_.s4.Bottleneckb1_pca750_RidgeCV.pth
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_regnety_640_Ch09_Xtfmer_.s4.Bottleneckb1_pca750_RidgeCV.pth
# JIT script saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_regnety_640_Ch09_Xtfmer_.s4.Bottleneckb1_pca750_RidgeCV_JITscript.pt
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_regnety_640_Ch09_meta_.s4.Bottleneckb1_pca750_RidgeCV.pkl
# Configuration saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/accentuation_configs/red_20250428-20240429/red_20250428-20240429_regnety_640_Ch9_accentuation_config.yaml
# Configuration loaded successfully
# Loaded configuration matches the original config
# Best config
# Best config - layer: .s4.Bottleneckb1, dimred: pca750, regressor: RidgeCV, train_score: 0.894, test_score: 0.891
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_regnety_640_Ch00_readout_.s4.Bottleneckb1_pca750_RidgeCV.pth
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_regnety_640_Ch00_Xtfmer_.s4.Bottleneckb1_pca750_RidgeCV.pth
# JIT script saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_regnety_640_Ch00_Xtfmer_.s4.Bottleneckb1_pca750_RidgeCV_JITscript.pt
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_regnety_640_Ch00_meta_.s4.Bottleneckb1_pca750_RidgeCV.pkl
# Configuration saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/accentuation_configs/red_20250428-20240429/red_20250428-20240429_regnety_640_Ch0_accentuation_config.yaml
# Configuration loaded successfully
# Loaded configuration matches the original config
# Best config
# Best config - layer: .s4.Bottleneckb1, dimred: pca750, regressor: RidgeCV, train_score: 0.916, test_score: 0.917
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_regnety_640_Ch19_readout_.s4.Bottleneckb1_pca750_RidgeCV.pth
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_regnety_640_Ch19_Xtfmer_.s4.Bottleneckb1_pca750_RidgeCV.pth
# JIT script saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_regnety_640_Ch19_Xtfmer_.s4.Bottleneckb1_pca750_RidgeCV_JITscript.pt
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_regnety_640_Ch19_meta_.s4.Bottleneckb1_pca750_RidgeCV.pkl
# Configuration saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/accentuation_configs/red_20250428-20240429/red_20250428-20240429_regnety_640_Ch19_accentuation_config.yaml
# Configuration loaded successfully
# Loaded configuration matches the original config
# Best config
# Best config - layer: .s4.Bottleneckb1, dimred: pca750, regressor: RidgeCV, train_score: 0.861, test_score: 0.710
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_regnety_640_Ch02_readout_.s4.Bottleneckb1_pca750_RidgeCV.pth
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_regnety_640_Ch02_Xtfmer_.s4.Bottleneckb1_pca750_RidgeCV.pth
# JIT script saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_regnety_640_Ch02_Xtfmer_.s4.Bottleneckb1_pca750_RidgeCV_JITscript.pt
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_regnety_640_Ch02_meta_.s4.Bottleneckb1_pca750_RidgeCV.pkl
# Configuration saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/accentuation_configs/red_20250428-20240429/red_20250428-20240429_regnety_640_Ch2_accentuation_config.yaml
# Configuration loaded successfully
# Loaded configuration matches the original config
# Best config
# Best config - layer: .features.MaxPool2d12, dimred: pca750, regressor: RidgeCV, train_score: 0.823, test_score: 0.741
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_AlexNet_training_seed_01_Ch15_readout_.features.MaxPool2d12_pca750_RidgeCV.pth
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_AlexNet_training_seed_01_Ch15_Xtfmer_.features.MaxPool2d12_pca750_RidgeCV.pth
# JIT script saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_AlexNet_training_seed_01_Ch15_Xtfmer_.features.MaxPool2d12_pca750_RidgeCV_JITscript.pt
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_AlexNet_training_seed_01_Ch15_meta_.features.MaxPool2d12_pca750_RidgeCV.pkl
# Configuration saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/accentuation_configs/red_20250428-20240429/red_20250428-20240429_AlexNet_training_seed_01_Ch15_accentuation_config.yaml
# Configuration loaded successfully
# Loaded configuration matches the original config
# Best config
# Best config - layer: .features.ReLU7, dimred: pca750, regressor: RidgeCV, train_score: 0.899, test_score: 0.874
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_AlexNet_training_seed_01_Ch09_readout_.features.ReLU7_pca750_RidgeCV.pth
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_AlexNet_training_seed_01_Ch09_Xtfmer_.features.ReLU7_pca750_RidgeCV.pth
# JIT script saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_AlexNet_training_seed_01_Ch09_Xtfmer_.features.ReLU7_pca750_RidgeCV_JITscript.pt
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_AlexNet_training_seed_01_Ch09_meta_.features.ReLU7_pca750_RidgeCV.pkl
# Configuration saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/accentuation_configs/red_20250428-20240429/red_20250428-20240429_AlexNet_training_seed_01_Ch9_accentuation_config.yaml
# Configuration loaded successfully
# Loaded configuration matches the original config
# Best config
# Best config - layer: .features.MaxPool2d12, dimred: pca750, regressor: RidgeCV, train_score: 0.804, test_score: 0.781
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_AlexNet_training_seed_01_Ch00_readout_.features.MaxPool2d12_pca750_RidgeCV.pth
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_AlexNet_training_seed_01_Ch00_Xtfmer_.features.MaxPool2d12_pca750_RidgeCV.pth
# JIT script saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_AlexNet_training_seed_01_Ch00_Xtfmer_.features.MaxPool2d12_pca750_RidgeCV_JITscript.pt
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_AlexNet_training_seed_01_Ch00_meta_.features.MaxPool2d12_pca750_RidgeCV.pkl
# Configuration saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/accentuation_configs/red_20250428-20240429/red_20250428-20240429_AlexNet_training_seed_01_Ch0_accentuation_config.yaml
# Configuration loaded successfully
# Loaded configuration matches the original config
# Best config
# Best config - layer: .features.ReLU7, dimred: pca750, regressor: RidgeCV, train_score: 0.856, test_score: 0.835
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_AlexNet_training_seed_01_Ch19_readout_.features.ReLU7_pca750_RidgeCV.pth
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_AlexNet_training_seed_01_Ch19_Xtfmer_.features.ReLU7_pca750_RidgeCV.pth
# JIT script saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_AlexNet_training_seed_01_Ch19_Xtfmer_.features.ReLU7_pca750_RidgeCV_JITscript.pt
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_AlexNet_training_seed_01_Ch19_meta_.features.ReLU7_pca750_RidgeCV.pkl
# Configuration saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/accentuation_configs/red_20250428-20240429/red_20250428-20240429_AlexNet_training_seed_01_Ch19_accentuation_config.yaml
# Configuration loaded successfully
# Loaded configuration matches the original config
# Best config
# Best config - layer: .features.MaxPool2d5, dimred: pca750, regressor: RidgeCV, train_score: 0.378, test_score: 0.244
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_AlexNet_training_seed_01_Ch02_readout_.features.MaxPool2d5_pca750_RidgeCV.pth
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_AlexNet_training_seed_01_Ch02_Xtfmer_.features.MaxPool2d5_pca750_RidgeCV.pth
# JIT script saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_AlexNet_training_seed_01_Ch02_Xtfmer_.features.MaxPool2d5_pca750_RidgeCV_JITscript.pt
# Saved /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_AlexNet_training_seed_01_Ch02_meta_.features.MaxPool2d5_pca750_RidgeCV.pkl
# Configuration saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/accentuation_configs/red_20250428-20240429/red_20250428-20240429_AlexNet_training_seed_01_Ch2_accentuation_config.yaml
# Configuration loaded successfully
# Loaded configuration matches the original config
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[14], line 92
#      90         output_yaml_path = f"{yaml_exportdir}/{subject_id}_{modelname}_Ch{unit_id}_accentuation_config.yaml"
#      91         save_and_verify_config(content, output_yaml_path, config)
# ---> 92 raise Exception
#
# Exception:

# %%
best_row = single_chan_result_df.query("dimred != 'srp'").sort_values('test_score', ascending=False).iloc[0]
print(f"Best config - layer: {best_row['layer']}, dimred: {best_row['dimred']}, regressor: {best_row['regressor']}, train_score: {best_row['train_score']:.3f}, test_score: {best_row['test_score']:.3f}")
# Out:
# Best config - layer: .layer4.Bottleneck2, dimred: pca750, regressor: RidgeCV, train_score: 0.896, test_score: 0.885

# %% [markdown]
# ### Scratch for creating yaml

# %%
import yaml

# %%
template_path = "/n/home12/binxuwang/Github/Closed-loop-visual-insilico/notebooks/accentuation_template.yaml"
with open(template_path, "r") as f:
    content = f.read()

# %%
import datetime
template_path = "/n/home12/binxuwang/Github/Closed-loop-visual-insilico/notebooks/accentuation_template.yaml"
with open(template_path, "r") as f:
    content = f.read()
content = content.replace("{{subject_id}}", subject_id)
content = content.replace("{{model_name}}", modelname)
content = content.replace("{{unit_ids}}", str([unit_id]))
# Replace template variables with actual values
content = content.replace("{{fit_method_name}}", regressor_name)
content = content.replace("{{layer_name}}", layername)
# outputdir already replaced above
content = content.replace("{{outputdir}}", exportdir)
content = content.replace("{{readout_path}}", export_readout_path)
content = content.replace("{{xtransform_path}}", export_Xtransform_JIT_path)
content = content.replace("{{meta_path}}", export_meta_path)
content = content.replace("{{date}}", datetime.datetime.now().strftime("%d-%m-%Y"))
yaml.safe_load(content)
# Out:
# {'model_name': 'resnet50_robust',
#  'fit_method_name': 'RidgeCV',
#  'unit_ids': '[15]',
#  'subject_id': 'red_20250428-20240429',
#  'layer_name': '.layer4.Bottleneck2',
#  'outputdir': '/n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429',
#  'readout_path': '/n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_robust_Ch15_readout_.layer4.Bottleneck2_pca750_RidgeCV.pth',
#  'xtransform_path': '/n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_robust_Ch15_Xtfmer_.layer4.Bottleneck2_pca750_RidgeCV_JITscript.pt',
#  'meta_path': '/n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_robust_Ch15_meta_.layer4.Bottleneck2_pca750_RidgeCV.pkl',
#  'result_folder': '/n/netscratch/kempner_fellows/Lab/tfel/prj_control/30-04-2025_resnet50_robust_accentuation',
#  'gifs_folder': '/n/netscratch/kempner_fellows/Lab/tfel/prj_control/30-04-2025_resnet50_robust_gifs',
#  'log_dir': '/n/netscratch/kempner_fellows/Lab/tfel/prj_control/30-04-2025_resnet50_robust_logs',
#  'seed_image_paths': ['shared1000/shared0631_nsd46161.png',
#   'shared1000/shared0131_nsd11160.png',
#   'shared1000/shared0196_nsd16467.png',
#   'shared1000/shared0147_nsd12066.png',
#   'shared1000/shared0491_nsd37225.png',
#   'shared1000/shared0485_nsd36911.png',
#   'shared1000/shared0862_nsd62480.png',
#   'shared1000/shared0255_nsd21193.png',
#   'shared1000/shared0974_nsd70506.png',
#   'shared1000/shared0189_nsd15794.png'],
#  'hp_tuning': {'enabled': True,
#   'num_images': 3,
#   'configs': [{'noise': 0.3,
#     'decay': 2.5,
#     'total_steps': 6000,
#     'learning_rate': 12.0,
#     'box_size': [0.9, 0.95]},
#    {'noise': 0.25,
#     'decay': 2.4,
#     'total_steps': 6000,
#     'learning_rate': 12.0,
#     'box_size': [0.9, 0.95]},
#    {'noise': 0.15,
#     'decay': 2.0,
#     'total_steps': 6000,
#     'learning_rate': 12.0,
#     'box_size': [0.9, 0.95]},
#    {'noise': 0.1,
#     'decay': 1.5,
#     'total_steps': 6000,
#     'learning_rate': 12.0,
#     'box_size': [0.9, 0.95]},
#    {'noise': 0.05,
#     'decay': 1.2,
#     'total_steps': 6000,
#     'learning_rate': 12.0,
#     'box_size': [0.9, 0.95]}]},
#  'fa_hyperparameters': {'noise': 0.1,
#   'decay': 1.5,
#   'total_steps': 6000,
#   'learning_rate': 12.0,
#   'image_size': 1024,
#   'model_input_size': 224,
#   'values_range': [0.0, 1.0],
#   'crops_per_iteration': 8,
#   'box_size': [0.9, 0.95],
#   'penalty': 0.0},
#  'extend_range': 0.25,
#  'num_levels': 11,
#  'generate_gifs': True,
#  'bicubic_interpolation': False,
#  'generate_comprehensive_gifs': True}

# %%
# Example usage:
content, config = create_accentuation_config(
    subject_id=subject_id,
    modelname=modelname,
    unit_id=unit_id,
    regressor_name=regressor_name,
    layername=layername,
    exportdir=exportdir,
    export_readout_path=export_readout_path,
    export_Xtransform_JIT_path=export_Xtransform_JIT_path,
    export_meta_path=export_meta_path
)
output_yaml_path = f"{exportdir}/{subject_id}_{modelname}_Ch{unit_id}_accentuation_config.yaml"
save_and_verify_config(content, output_yaml_path, config)
# Out:
# Configuration saved to /n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_robust_Ch15_accentuation_config.yaml
# Configuration loaded successfully
# Loaded configuration matches the original config
# '/n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_robust_Ch15_accentuation_config.yaml'

# %%
config
# Out:
# {'model_name': 'resnet50_robust',
#  'fit_method_name': 'RidgeCV',
#  'unit_ids': [15],
#  'subject_id': 'red_20250428-20240429',
#  'layer_name': '.layer4.Bottleneck2',
#  'outputdir': '/n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429',
#  'readout_path': '/n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_robust_Ch15_readout_.layer4.Bottleneck2_pca750_RidgeCV.pth',
#  'xtransform_path': '/n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_robust_Ch15_Xtfmer_.layer4.Bottleneck2_pca750_RidgeCV_JITscript.pt',
#  'meta_path': '/n/holylabs/LABS/alvarez_lab/Lab/VVS_Accentuation/Encoding_model_outputs/red_20250428-20240429/red_20250428-20240429_resnet50_robust_Ch15_meta_.layer4.Bottleneck2_pca750_RidgeCV.pkl',
#  'result_folder': '/n/netscratch/kempner_fellows/Lab/tfel/prj_control/30-04-2025_resnet50_robust_accentuation',
#  'gifs_folder': '/n/netscratch/kempner_fellows/Lab/tfel/prj_control/30-04-2025_resnet50_robust_gifs',
#  'log_dir': '/n/netscratch/kempner_fellows/Lab/tfel/prj_control/30-04-2025_resnet50_robust_logs',
#  'seed_image_paths': ['shared1000/shared0631_nsd46161.png',
#   'shared1000/shared0131_nsd11160.png',
#   'shared1000/shared0196_nsd16467.png',
#   'shared1000/shared0147_nsd12066.png',
#   'shared1000/shared0491_nsd37225.png',
#   'shared1000/shared0485_nsd36911.png',
#   'shared1000/shared0862_nsd62480.png',
#   'shared1000/shared0255_nsd21193.png',
#   'shared1000/shared0974_nsd70506.png',
#   'shared1000/shared0189_nsd15794.png'],
#  'hp_tuning': {'enabled': True,
#   'num_images': 3,
#   'configs': [{'noise': 0.3,
#     'decay': 2.5,
#     'total_steps': 6000,
#     'learning_rate': 12.0,
#     'box_size': [0.9, 0.95]},
#    {'noise': 0.25,
#     'decay': 2.4,
#     'total_steps': 6000,
#     'learning_rate': 12.0,
#     'box_size': [0.9, 0.95]},
#    {'noise': 0.15,
#     'decay': 2.0,
#     'total_steps': 6000,
#     'learning_rate': 12.0,
#     'box_size': [0.9, 0.95]},
#    {'noise': 0.1,
#     'decay': 1.5,
#     'total_steps': 6000,
#     'learning_rate': 12.0,
#     'box_size': [0.9, 0.95]},
#    {'noise': 0.05,
#     'decay': 1.2,
#     'total_steps': 6000,
#     'learning_rate': 12.0,
#     'box_size': [0.9, 0.95]}]},
#  'fa_hyperparameters': {'noise': 0.1,
#   'decay': 1.5,
#   'total_steps': 6000,
#   'learning_rate': 12.0,
#   'image_size': 1024,
#   'model_input_size': 224,
#   'values_range': [0.0, 1.0],
#   'crops_per_iteration': 8,
#   'box_size': [0.9, 0.95],
#   'penalty': 0.0},
#  'extend_range': 0.25,
#  'num_levels': 11,
#  'generate_gifs': True,
#  'bicubic_interpolation': False,
#  'generate_comprehensive_gifs': True}

# %%
yaml.safe_load(content.replace('"{{unit_ids}}"', str([0])))
# Out:
# {'model_name': 'AlexNet_training_seed_01',
#  'fit_method_name': '{{fit_method_name}}',
#  'unit_ids': [0],
#  'subject_id': '{{subject_id}}',
#  'layer_name': '{{layer_name}}',
#  'outputdir': '{{outputdir}}',
#  'readout_path': '{{readout_path}}',
#  'xtransform_path': '{{xtransform_path}}',
#  'meta_path': '{{meta_path}}',
#  'result_folder': '/n/netscratch/kempner_fellows/Lab/tfel/prj_control/{{date}}_AlexNet_training_seed_01_accentuation',
#  'gifs_folder': '/n/netscratch/kempner_fellows/Lab/tfel/prj_control/{{date}}_AlexNet_training_seed_01_gifs',
#  'log_dir': '/n/netscratch/kempner_fellows/Lab/tfel/prj_control/{{date}}_AlexNet_training_seed_01_logs',
#  'seed_image_paths': ['shared1000/shared0631_nsd46161.png',
#   'shared1000/shared0131_nsd11160.png',
#   'shared1000/shared0196_nsd16467.png',
#   'shared1000/shared0147_nsd12066.png',
#   'shared1000/shared0491_nsd37225.png',
#   'shared1000/shared0485_nsd36911.png',
#   'shared1000/shared0862_nsd62480.png',
#   'shared1000/shared0255_nsd21193.png',
#   'shared1000/shared0974_nsd70506.png',
#   'shared1000/shared0189_nsd15794.png'],
#  'hp_tuning': {'enabled': True,
#   'num_images': 3,
#   'configs': [{'noise': 0.3,
#     'decay': 2.5,
#     'total_steps': 6000,
#     'learning_rate': 12.0,
#     'box_size': [0.9, 0.95]},
#    {'noise': 0.25,
#     'decay': 2.4,
#     'total_steps': 6000,
#     'learning_rate': 12.0,
#     'box_size': [0.9, 0.95]},
#    {'noise': 0.15,
#     'decay': 2.0,
#     'total_steps': 6000,
#     'learning_rate': 12.0,
#     'box_size': [0.9, 0.95]},
#    {'noise': 0.1,
#     'decay': 1.5,
#     'total_steps': 6000,
#     'learning_rate': 12.0,
#     'box_size': [0.9, 0.95]},
#    {'noise': 0.05,
#     'decay': 1.2,
#     'total_steps': 6000,
#     'learning_rate': 12.0,
#     'box_size': [0.9, 0.95]}]},
#  'fa_hyperparameters': {'noise': 0.1,
#   'decay': 1.5,
#   'total_steps': 6000,
#   'learning_rate': 12.0,
#   'image_size': 1024,
#   'model_input_size': 224,
#   'values_range': [0.0, 1.0],
#   'crops_per_iteration': 8,
#   'box_size': [0.9, 0.95],
#   'penalty': 0.0},
#  'extend_range': 0.25,
#  'num_levels': 11,
#  'generate_gifs': True,
#  'bicubic_interpolation': False,
#  'generate_comprehensive_gifs': True}

# %%
content
# Out:
# 'model_name: "{{model_name}}"  \nfit_method_name: "{{fit_method_name}}"  \n\n# Units to process\nunit_ids: "{{unit_ids}}"\n\n# Model and data paths\nsubject_id: "{{subject_id}}"  \nlayer_name: "{{layer_name}}"  \noutputdir: "{{outputdir}}"\nreadout_path: "{{readout_path}}"\nxtransform_path: "{{xtransform_path}}"\nmeta_path: "{{meta_path}}"\n\n\n# Paths\nresult_folder: "/n/netscratch/kempner_fellows/Lab/tfel/prj_control/{{date}}_{{model_name}}_accentuation"\ngifs_folder: "/n/netscratch/kempner_fellows/Lab/tfel/prj_control/{{date}}_{{model_name}}_gifs"\nlog_dir: "/n/netscratch/kempner_fellows/Lab/tfel/prj_control/{{date}}_{{model_name}}_logs"\n\n\n# Input images\nseed_image_paths:\n  - "shared1000/shared0631_nsd46161.png"\n  - "shared1000/shared0131_nsd11160.png"\n  - "shared1000/shared0196_nsd16467.png"\n  - "shared1000/shared0147_nsd12066.png"\n  - "shared1000/shared0491_nsd37225.png"\n  - "shared1000/shared0485_nsd36911.png"\n  - "shared1000/shared0862_nsd62480.png"\n  - "shared1000/shared0255_nsd21193.png"\n  - "shared1000/shared0974_nsd70506.png"\n  - "shared1000/shared0189_nsd15794.png"\n\n# Hyperparameter tuning settings\nhp_tuning:\n  enabled: true\n  num_images: 3  # Number of images to use for tuning\n  configs:\n    - noise: 0.30\n      decay: 2.5\n      total_steps: 6000\n      learning_rate: 12.0\n      box_size: [0.90, 0.95]\n    - noise: 0.25\n      decay: 2.4\n      total_steps: 6000\n      learning_rate: 12.0\n      box_size: [0.90, 0.95]\n    - noise: 0.15\n      decay: 2.0\n      total_steps: 6000\n      learning_rate: 12.0\n      box_size: [0.90, 0.95]\n    - noise: 0.1\n      decay: 1.5\n      total_steps: 6000\n      learning_rate: 12.0\n      box_size: [0.90, 0.95]\n    - noise: 0.05\n      decay: 1.2\n      total_steps: 6000\n      learning_rate: 12.0\n      box_size: [0.90, 0.95]\n\n# Feature Accentuation hyperparameters (default if tuning is disabled)\nfa_hyperparameters:\n  noise: 0.1\n  decay: 1.5\n  total_steps: 6000\n  learning_rate: 12.0\n  image_size: 1024\n  model_input_size: 224\n  values_range: [0.0, 1.0]\n  crops_per_iteration: 8\n  box_size: [0.90, 0.95]\n  penalty: 0.0\n\n# Other settings\nextend_range: 0.25  # Percentage to extend range of target levels\nnum_levels: 11      # Number of target levels to generate\ngenerate_gifs: true\nbicubic_interpolation: false\ngenerate_comprehensive_gifs: true'
