# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
sys.path.append("/n/home12/binxuwang/Github/Closed-loop-visual-insilico")
import timm
import torch
import torch as th
import torch.nn as nn
from torchvision.models.feature_extraction import create_feature_extractor
from tqdm.auto import tqdm
from os.path import join
import pickle as pkl
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from horama import maco, plot_maco
import torchvision.transforms as T
from torchvision.transforms import ToPILImage, ToTensor, Normalize, Resize
from torchvision.models import resnet50
from circuit_toolkit.CNN_scorers import TorchScorer
from circuit_toolkit.GAN_utils import upconvGAN, Caffenet
from circuit_toolkit.plot_utils import to_imgrid, show_imgrid, save_imgrid, saveallforms
from circuit_toolkit.layer_hook_utils import featureFetcher_module, featureFetcher, get_module_names
from circuit_toolkit.dataset_utils import ImagePathDataset
from torch.utils.data import DataLoader
from neural_regress.regress_lib import sweep_regressors, perform_regression_sweeplayer_RidgeCV, perform_regression_sweeplayer, record_features
from neural_regress.sklearn_torchify_lib import SRP_torch, PCA_torch, LinearRegression_torch, SpatialAvg_torch, LinearLayer_from_sklearn
from core.data_utils import load_neural_data, load_from_hdf5, load_neural_trial_resp_tensor, create_response_tensor, parse_image_fullpaths
# Out:
# Warning: skimage.transform is not available. Will use scipy.misc.imresize instead.
# Warning: skimage.transform is not available. Will use scipy.misc.imresize instead.

# %%
def load_model_transform(modelname, device="cuda"):
    # Prepare model and transforms
    if modelname == "resnet50_robust":
        model = resnet50(pretrained=False)
        model.load_state_dict(th.load("/n/home12/binxuwang/Github/Closed-loop-visual-insilico/checkpoints/imagenet_linf_8_pure.pt"))
        transforms_pipeline = T.Compose([
            T.ToTensor(),
            T.Resize((224, 224)),
            T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
        ])
    elif modelname == "resnet50":
        model = resnet50(pretrained=True)
        transforms_pipeline = T.Compose([
            T.ToTensor(),
            T.Resize((224, 224)),
            T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
        ])
    elif modelname == "resnet50_clip":
        import clip
        model_clip, preprocess = clip.load('RN50', device=device)
        model = model_clip.visual
        transforms_pipeline = preprocess
    elif modelname == "resnet50_dino":
        # https://github.com/facebookresearch/dino
        model = torch.hub.load('facebookresearch/dino:main', 'dino_resnet50')
        transforms_pipeline = T.Compose([
            T.ToTensor(),
            T.Resize((224, 224)),
            T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
        ])
    else:
        raise ValueError(f"Unknown model: {modelname}")
        # model = timm.create_model(modelname, pretrained=True).to(device).eval()
        # data_config = timm.data.resolve_model_data_config(model)
        # transforms_pipeline = timm.data.create_transform(**data_config, is_training=False)
    model = model.to(device).eval()
    model.requires_grad_(False)
    
    return model, transforms_pipeline

# %%
# def extract_features(model, dataset, layer_name="last_block", batch_size=20, device="cuda"):
#     """Extract features from a specified layer of the model."""
#     fetcher = featureFetcher_module()
#     fetcher.record_module(model.layer4, layer_name, ) # this is for ResNet50, specifically, modify as needed
#     feat_dict = record_features(model, fetcher, dataset, batch_size=batch_size, device=device)
#     fetcher.cleanup()
#     del fetcher
#     return feat_dict

from sklearn.model_selection import train_test_split, GridSearchCV


def compute_D2_per_unit(rspavg_resp_peak, rspavg_pred):
    return 1 - np.square(rspavg_resp_peak - rspavg_pred).sum(axis=0) / np.square(rspavg_resp_peak - rspavg_resp_peak.mean(axis=0)).sum(axis=0)

# %%
dataroot = r"/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation"
stimroot = join(dataroot, "Stimuli", "shared1000") #/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/Stimuli/shared1000
pilot_MACO_root = join(dataroot, "Stimuli", "stimuli_pilot_20241119", "results")
data_path = join(dataroot, "vvs-accentuate-day1_normalize_paul_241119-241122.h5") #"vvs-accentuate-day1_normalize_paul_241119.h5")
data = load_from_hdf5(data_path)
# subjects: ['paul_20241119', 'paul_241119']
subject_id = 'paul_20241119-20241122' #'paul_20241119'
data_dict = load_neural_data(data_path, subject_id=subject_id, stimroot=stimroot)
stim_names, rspavg_resp_peak, resp_tensor, trial_counters = load_neural_trial_resp_tensor(data_path, subject_id)
image_fps = parse_image_fullpaths(stim_names, [stimroot, pilot_MACO_root])
# Out:
# Trials shape: (7174,) (7174, 64)
# Rspavg shape: (1028,) (1028, 64)
# Response tensor shape (stimulus x neuron x trial): (1028, 64, 8)
# Response tensor shape: (1028, 64, 8)
# Trial counters shape: (1028,)
# min and max trial counters: 5 8
# All stimulus files were found

# %%
# !ls {join(dataroot, "model_outputs")}/paul_20241119/*_Xtfmer_RidgeCV.pkl
# Out:
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/model_outputs/paul_20241119/paul_20241119_resnet50_clip_sweep_regressors_highreliab_layers_Xtfmer_RidgeCV.pkl
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/model_outputs/paul_20241119/paul_20241119_resnet50_dino_sweep_regressors_highreliab_layers_Xtfmer_RidgeCV.pkl
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/model_outputs/paul_20241119/paul_20241119_resnet50_robust_sweep_regressors_highreliab_layers_Xtfmer_RidgeCV.pkl
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/model_outputs/paul_20241119/paul_20241119_resnet50_sweep_regressors_highreliab_layers_Xtfmer_RidgeCV.pkl

# %%
for fps in image_fps:
    if not os.path.exists(fps):
        print(fps)
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/Stimuli/stimuli_pilot_20241119/results
# Out:
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_neg_0_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_neg_0_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_neg_1_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_neg_1_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_neg_2_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_neg_2_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_neg_3_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_neg_3_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_neg_4_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_neg_4_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_neg_5_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_neg_5_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_neg_6_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_neg_6_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_neg_7_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_neg_7_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_pos_0_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_pos_0_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_pos_1_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_pos_1_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_pos_2_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_pos_2_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_pos_3_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_pos_3_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_pos_4_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_pos_4_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_pos_5_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_pos_5_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_pos_6_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_pos_6_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_pos_7_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_pos_7_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_neg_0_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_neg_0_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_neg_1_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_neg_1_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_neg_2_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_neg_2_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_neg_3_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_neg_3_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_neg_4_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_neg_4_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_neg_5_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_neg_5_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_neg_6_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_neg_6_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_neg_7_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_neg_7_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_pos_0_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_pos_0_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_pos_1_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_pos_1_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_pos_2_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_pos_2_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_pos_3_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_pos_3_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_pos_4_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_pos_4_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_pos_5_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_pos_5_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_pos_6_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_pos_6_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_pos_7_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_pos_7_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_001_adult-1.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_002_adult-2.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_003_adult-3.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_004_adult-4.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_005_adult-5.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_006_adult-6.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_007_adult-7.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_008_adult-8.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_009_adult-9.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_010_adult-10.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_011_body-1.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_012_body-2.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_013_body-3.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_014_body-4.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_015_body-5.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_016_body-6.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_017_body-7.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_018_body-8.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_019_body-9.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_020_body-10.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_021_car-1.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_022_car-2.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_023_car-3.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_024_car-4.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_025_car-5.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_026_car-6.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_027_car-7.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_028_car-8.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_029_car-9.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_030_car-10.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_031_child-1.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_032_child-2.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_033_child-3.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_034_child-4.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_035_child-5.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_036_child-6.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_037_child-7.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_038_child-8.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_039_child-9.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_040_child-10.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_041_corridor-1.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_042_corridor-2.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_043_corridor-3.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_044_corridor-4.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_045_corridor-5.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_046_corridor-6.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_047_corridor-7.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_048_corridor-8.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_049_corridor-9.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_050_corridor-10.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_051_house-1.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_052_house-2.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_053_house-3.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_054_house-4.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_055_house-5.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_056_house-6.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_057_house-7.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_058_house-8.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_059_house-9.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_060_house-10.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_061_instrument-1.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_062_instrument-2.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_063_instrument-3.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_064_instrument-4.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_065_instrument-5.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_066_instrument-6.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_067_instrument-7.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_068_instrument-8.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_069_instrument-9.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_070_instrument-10.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_071_limb-1.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_072_limb-2.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_073_limb-3.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_074_limb-4.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_075_limb-5.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_076_limb-6.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_077_limb-7.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_078_limb-8.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_079_limb-9.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_080_limb-10.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_091_scrambled-1.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_092_scrambled-2.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_093_scrambled-3.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_094_scrambled-4.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_095_scrambled-5.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_096_scrambled-6.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_097_scrambled-7.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_098_scrambled-8.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_099_scrambled-9.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_100_scrambled-10.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_101_word-1.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_102_word-2.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_103_word-3.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_104_word-4.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_105_word-5.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_106_word-6.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_107_word-7.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_108_word-8.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_109_word-9.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_110_word-10.jpg
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_neg_0_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_neg_0_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_neg_1_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_neg_1_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_neg_2_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_neg_2_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_neg_3_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_neg_3_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_neg_4_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_neg_4_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_neg_5_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_neg_5_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_neg_6_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_neg_6_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_neg_7_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_neg_7_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_pos_0_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_pos_0_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_pos_1_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_pos_1_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_pos_2_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_pos_2_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_pos_3_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_pos_3_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_pos_4_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_pos_4_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_pos_5_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_pos_5_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_pos_6_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_pos_6_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_pos_7_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_pos_7_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_neg_0_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_neg_0_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_neg_1_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_neg_1_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_neg_2_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_neg_2_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_neg_3_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_neg_3_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_neg_4_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_neg_4_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_neg_5_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_neg_5_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_neg_6_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_neg_6_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_neg_7_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_neg_7_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_pos_0_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_pos_0_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_pos_1_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_pos_1_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_pos_2_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_pos_2_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_pos_3_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_pos_3_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_pos_4_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_pos_4_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_pos_5_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_pos_5_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_pos_6_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_pos_6_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_pos_7_2048_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_pos_7_512_tr.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0001_nsd02951.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0002_nsd02991.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0003_nsd03050.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0005_nsd03147.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0006_nsd03158.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0007_nsd03165.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0008_nsd03172.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0009_nsd03182.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0010_nsd03387.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0011_nsd03435.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0012_nsd03450.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0013_nsd03490.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0014_nsd03627.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0016_nsd03688.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0017_nsd03730.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0018_nsd03810.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0019_nsd03843.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0020_nsd03848.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0021_nsd03857.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0022_nsd03914.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0023_nsd03952.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0024_nsd04052.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0025_nsd04059.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0026_nsd04130.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0027_nsd04157.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0028_nsd04250.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0029_nsd04326.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0030_nsd04424.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0031_nsd04437.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0032_nsd04613.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0033_nsd04668.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0035_nsd04769.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0036_nsd04787.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0038_nsd04870.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0039_nsd04893.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0041_nsd05035.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0042_nsd05107.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0043_nsd05205.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0044_nsd05286.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0045_nsd05302.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0047_nsd05428.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0048_nsd05460.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0050_nsd05543.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0051_nsd05575.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0053_nsd05603.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0054_nsd05715.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0056_nsd05891.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0057_nsd06133.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0058_nsd06200.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0059_nsd06223.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0060_nsd06432.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0061_nsd06445.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0062_nsd06490.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0063_nsd06515.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0064_nsd06522.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0065_nsd06525.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0066_nsd06559.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0067_nsd06641.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0068_nsd06714.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0070_nsd07008.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0071_nsd07040.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0072_nsd07121.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0073_nsd07208.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0074_nsd07337.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0075_nsd07367.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0076_nsd07410.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0078_nsd07481.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0079_nsd07655.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0080_nsd07660.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0081_nsd07841.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0083_nsd07945.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0087_nsd08110.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0088_nsd08205.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0089_nsd08226.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0090_nsd08263.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0091_nsd08275.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0092_nsd08319.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0094_nsd08395.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0095_nsd08416.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0096_nsd08436.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0097_nsd08466.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0098_nsd08510.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0099_nsd08632.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0100_nsd08647.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0101_nsd08808.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0102_nsd08844.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0103_nsd08926.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0104_nsd08934.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0105_nsd09028.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0107_nsd09148.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0108_nsd09231.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0109_nsd09435.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0110_nsd09463.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0112_nsd09723.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0113_nsd09805.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0114_nsd09848.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0115_nsd09866.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0116_nsd09918.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0117_nsd09979.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0118_nsd10007.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0119_nsd10047.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0120_nsd10065.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0123_nsd10245.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0125_nsd10472.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0126_nsd10508.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0127_nsd10587.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0129_nsd10611.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0130_nsd10908.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0131_nsd11160.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0133_nsd11488.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0134_nsd11522.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0135_nsd11567.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0136_nsd11618.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0137_nsd11636.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0139_nsd11726.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0140_nsd11797.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0141_nsd11828.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0142_nsd11838.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0143_nsd11845.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0144_nsd11933.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0145_nsd11943.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0146_nsd11953.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0147_nsd12066.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0149_nsd12215.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0151_nsd12488.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0153_nsd12635.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0155_nsd12797.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0156_nsd12799.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0157_nsd12923.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0158_nsd12938.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0159_nsd13139.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0160_nsd13231.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0162_nsd13315.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0163_nsd13614.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0164_nsd13654.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0165_nsd13663.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0166_nsd13721.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0167_nsd13847.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0168_nsd14111.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0169_nsd14122.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0170_nsd14166.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0171_nsd14180.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0172_nsd14444.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0173_nsd14529.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0174_nsd14568.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0175_nsd14595.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0176_nsd14611.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0177_nsd14645.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0178_nsd14794.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0180_nsd14821.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0181_nsd14899.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0182_nsd14932.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0183_nsd15004.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0184_nsd15026.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0185_nsd15129.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0186_nsd15365.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0187_nsd15493.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0188_nsd15507.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0189_nsd15794.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0190_nsd15820.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0192_nsd16064.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0193_nsd16253.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0194_nsd16345.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0195_nsd16422.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0196_nsd16467.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0198_nsd16636.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0199_nsd16656.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0200_nsd16703.png
# ...
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0824_nsd59818.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0828_nsd60187.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0829_nsd60252.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0830_nsd60306.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0831_nsd60457.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0832_nsd60506.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0833_nsd60520.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0834_nsd60554.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0835_nsd60726.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0836_nsd60835.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0838_nsd60868.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0839_nsd60979.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0840_nsd61123.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0841_nsd61134.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0842_nsd61178.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0843_nsd61217.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0844_nsd61511.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0845_nsd61514.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0846_nsd61678.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0847_nsd61739.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0848_nsd61749.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0850_nsd61798.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0852_nsd61810.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0853_nsd61874.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0854_nsd61973.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0855_nsd62007.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0857_nsd62210.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0859_nsd62276.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0860_nsd62303.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0862_nsd62480.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0863_nsd62545.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0864_nsd62562.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0865_nsd62684.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0867_nsd62961.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0868_nsd63082.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0869_nsd63183.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0870_nsd63346.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0871_nsd63450.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0872_nsd63747.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0875_nsd63923.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0876_nsd63932.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0877_nsd63945.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0878_nsd64005.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0879_nsd64097.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0880_nsd64296.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0881_nsd64484.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0882_nsd64499.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0883_nsd64616.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0884_nsd64622.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0885_nsd64688.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0886_nsd64772.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0887_nsd64868.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0888_nsd64881.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0889_nsd64894.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0890_nsd64980.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0891_nsd65011.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0892_nsd65070.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0894_nsd65188.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0895_nsd65233.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0896_nsd65254.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0897_nsd65268.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0899_nsd65415.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0900_nsd65446.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0901_nsd65640.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0902_nsd65655.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0903_nsd65687.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0904_nsd65770.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0905_nsd65800.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0907_nsd65873.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0908_nsd65921.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0911_nsd66215.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0913_nsd66279.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0914_nsd66331.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0915_nsd66343.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0916_nsd66422.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0917_nsd66465.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0918_nsd66480.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0919_nsd66490.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0920_nsd66581.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0921_nsd66644.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0922_nsd66774.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0924_nsd66947.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0930_nsd67238.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0932_nsd67296.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0934_nsd67743.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0936_nsd67830.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0937_nsd68024.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0938_nsd68169.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0939_nsd68279.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0940_nsd68312.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0941_nsd68340.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0942_nsd68419.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0944_nsd68742.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0945_nsd68815.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0946_nsd68843.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0947_nsd68859.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0948_nsd68898.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0950_nsd69026.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0951_nsd69031.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0953_nsd69215.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0954_nsd69241.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0955_nsd69443.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0956_nsd69503.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0957_nsd69615.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0958_nsd69617.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0959_nsd69786.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0960_nsd69814.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0961_nsd69832.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0962_nsd69840.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0963_nsd69855.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0964_nsd69919.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0965_nsd70039.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0966_nsd70076.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0967_nsd70096.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0968_nsd70194.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0969_nsd70233.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0972_nsd70369.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0973_nsd70428.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0974_nsd70506.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0979_nsd70765.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0980_nsd70948.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0981_nsd71026.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0982_nsd71187.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0983_nsd71230.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0984_nsd71233.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0985_nsd71242.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0986_nsd71411.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0987_nsd71451.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0988_nsd71754.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0989_nsd71895.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0990_nsd71929.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0994_nsd72210.png
# /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0995_nsd72258.png

# %%
data_dict = load_neural_data(data_path, subject_id, stimroot)
image_fps = data_dict['image_fps']
resp_mat = data_dict['resp_mat']
reliability = data_dict['reliability']
ncsnr = data_dict['ncsnr']

# %%
stimroot = join(dataroot, "Stimuli", "shared1000")
pilotroot = join(dataroot, "Stimuli", "stimuli_pilot_20241119", "results")

# %%
from sklearn.model_selection import train_test_split, GridSearchCV

def compute_D2_per_unit(rspavg_resp_peak, rspavg_pred):
    return 1 - np.square(rspavg_resp_peak - rspavg_pred).sum(axis=0) / np.square(rspavg_resp_peak - rspavg_resp_peak.mean(axis=0)).sum(axis=0)

idx_train, idx_test = train_test_split(
    np.arange(len(rspavg_resp_peak)), test_size=0.2, random_state=42, shuffle=True
)

# %%
dataroot = r"/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation"
stimroot = join(dataroot, "Stimuli", "shared1000") #/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/Stimuli/shared1000
pilot_MACO_root = join(dataroot, "Stimuli", "stimuli_pilot_20241119", "results")
data_path = join(dataroot, "vvs-accentuate-day1_normalize_paul_241119-241122.h5")
subject_id = 'paul_20241119-20241122'
PCA_subject_id = 'paul_20241119'
batch_size = 96 
device = "cuda" 
reliability_thresh = None
# Load data
data_dict = load_neural_data(data_path, subject_id, stimroot)
stim_names = data_dict['stimulus_names']
image_fps = parse_image_fullpaths(stim_names, [stimroot, pilot_MACO_root])
resp_mat = data_dict['resp_mat']
reliability = data_dict['reliability']
ncsnr = data_dict['ncsnr']
print(f"Loading data from {data_path}")
figroot = join(dataroot, "model_outputs")
figdir = join(dataroot, "model_outputs", subject_id, )
os.makedirs(figdir, exist_ok=True)
for modelname in ["resnet50_robust", ]: # "resnet50_clip", "resnet50_dino", "resnet50", 
    print(f"Fitting models for subject {subject_id} with {modelname} model | {len(ncsnr)} channels")
    model, transforms_pipeline = load_model_transform(modelname, device=device)
    # Prepare dataset
    dataset = ImagePathDataset(image_fps, scores=resp_mat, transform=transforms_pipeline)

    batch_size = 96
    fetcher = featureFetcher(model, input_size=(3, 224, 224), print_module=False)
    
    module_names = [name for name in fetcher.module_names.values() if "Bottleneck" in name and ("layer4" in name )] # or "layer3" in name
    print(module_names)
    for name in module_names: 
        fetcher.record(name, store_device='cpu', ingraph=False, )
    feat_dict_lyrswp = record_features(model, fetcher, dataset, batch_size=batch_size, device=device)
    fetcher.cleanup()

    thresh = reliability_thresh
    if thresh is None:
        chan_mask = np.ones(len(ncsnr), dtype=bool)
    else:
        chan_mask = reliability > thresh
    resp_mat_sel = resp_mat[:, chan_mask]
    print(f"Fitting models for reliable channels > {thresh} N={chan_mask.sum()}")
    if os.path.exists(join(figroot, PCA_subject_id, f"{PCA_subject_id}_{modelname}_sweep_regressors_highreliab_layers_Xtfmer_RidgeCV.pkl")):
        Xtfmer_lyrswp_RidgeCV = th.load(join(figroot, PCA_subject_id, f"{PCA_subject_id}_{modelname}_sweep_regressors_highreliab_layers_Xtfmer_RidgeCV.pkl"), )
    else:
        Xtfmer_lyrswp_RidgeCV = {}
    result_df_lyrswp_RidgeCV, fit_models_lyrswp_RidgeCV, Xdict_lyrswp_RidgeCV, Xtfmer_lyrswp_RidgeCV = perform_regression_sweeplayer_RidgeCV(feat_dict_lyrswp, resp_mat_sel, 
                                                                            layer_names=module_names, dimred_list=["srp", "pca1000"], 
                                                                        alpha_list=[1E-4, 1E-3, 1E-2, 1E-1, 1, 10, 100, 1E3, 1E4, 1E5, 1E6, 1E7, 1E8, 1E9],
                                                                        verbose=True, pretrained_Xtransforms=Xtfmer_lyrswp_RidgeCV)
    result_df_lyrswp_RidgeCV.to_csv(join(figdir, f"{subject_id}_{modelname}_sweep_regressors_highreliab_layers_sweep_RidgeCV.csv"))
    th.save(fit_models_lyrswp_RidgeCV, join(figdir, f"{subject_id}_{modelname}_sweep_regressors_highreliab_layers_fitmodels_RidgeCV.pth")) 
    th.save(Xtfmer_lyrswp_RidgeCV, join(figdir, f"{subject_id}_{modelname}_sweep_regressors_highreliab_layers_Xtfmer_RidgeCV.pkl"))
    
    # summarize prediction and evaluation
    pred_dict = {}
    D2_per_unit_train_dict = {}
    D2_per_unit_test_dict = {}
    D2_per_unit_dict = {}
    for (model_dimred, regressor) in fit_models_lyrswp_RidgeCV.keys():
        fit_model = fit_models_lyrswp_RidgeCV[(model_dimred, regressor)]
        Xfeat = Xdict_lyrswp_RidgeCV[(model_dimred)]
        # Xfeat_tfmer = Xtfmer_lyrswp_RidgeCV[(model_dimred)]
        rspavg_pred = fit_model.predict(Xfeat)
        pred_dict[(model_dimred, regressor)] = rspavg_pred
        D2_per_unit = compute_D2_per_unit(resp_mat_sel, rspavg_pred)
        D2_per_unit_train = compute_D2_per_unit(resp_mat_sel[idx_train], rspavg_pred[idx_train])
        D2_per_unit_test = compute_D2_per_unit(resp_mat_sel[idx_test], rspavg_pred[idx_test])
        D2_per_unit_train_dict[(model_dimred, regressor)] = D2_per_unit_train
        D2_per_unit_test_dict[(model_dimred, regressor)] = D2_per_unit_test

    pkl.dump({
        "pred_dict": pred_dict,
        "D2_per_unit_dict": D2_per_unit_dict,
        "D2_per_unit_train_dict": D2_per_unit_train_dict,
        "D2_per_unit_test_dict": D2_per_unit_test_dict,
    }, open(join(figdir, f"{subject_id}_{modelname}_sweep_regressors_layers_pred_meta.pkl"), "wb"))

    figh, axs = plt.subplots(3, 2, figsize=(8, 12))
    for (model_dimred, regressor), ax in zip(D2_per_unit_test_dict.keys(), axs.flatten()):
        plt.sca(ax)
        plt.scatter(ncsnr, D2_per_unit_test_dict[(model_dimred, regressor)], label="test", marker="o", alpha=0.5)
        plt.scatter(ncsnr, D2_per_unit_train_dict[(model_dimred, regressor)], label="train", marker="x", alpha=0.5)
        plt.ylim(None, 1.05)
        plt.xlabel("ncsnr")
        plt.legend()
        plt.ylabel("D2 per unit")
        plt.title(f"{model_dimred}\n{regressor} D2 per unit\n[test avg {D2_per_unit_test_dict[(model_dimred, regressor)].mean():.2f} train avg {D2_per_unit_train_dict[(model_dimred, regressor)].mean():.2f}]")
    plt.suptitle(f"{subject_id} {modelname} layer sweep [train and test splits]")
    plt.tight_layout()
    saveallforms(figdir, f"{subject_id}_{modelname}_layer_sweep_GridCV_synopisis_D2perunit_ncsnr_scatter")
    plt.show()
    
    
    # for half the layers (later half) ~ 20 mins
    result_df_lyrswp_formatted = result_df_lyrswp_RidgeCV.reset_index()
    result_df_lyrswp_formatted.rename(columns={"level_0": "layer_dimred", "level_1": "regressor", }, inplace=True)
    result_df_lyrswp_formatted["layer"] = result_df_lyrswp_formatted["layer_dimred"].apply(lambda x: x.split("_")[0])
    result_df_lyrswp_formatted["dimred"] = result_df_lyrswp_formatted["layer_dimred"].apply(lambda x: x.split("_")[-1])
    result_df_lyrswp_formatted.to_csv(join(figdir, f"{subject_id}_{modelname}_sweep_regressors_highreliab_layers_sweep_RidgeCV_formatted.csv"))
    
    figh, axs = plt.subplots(1, 2, figsize=(10, 5))
    plt.sca(axs[0])
    sns.lineplot(data=result_df_lyrswp_formatted, x="layer", 
            y="train_score", style="regressor", hue="dimred", ax=axs[0], marker="o")
    plt.xticks(rotation=45)
    xticklabels = plt.gca().get_xticklabels()
    xticklabels = [label.get_text().replace("Bottleneck", "B").replace(".layer", "L") for label in xticklabels]
    plt.xticks(ticks=range(len(xticklabels)), labels=xticklabels, rotation=45)
    plt.title("Training R2")

    plt.sca(axs[1])
    sns.lineplot(data=result_df_lyrswp_formatted, x="layer", 
            y="test_score", style="regressor", hue="dimred", ax=axs[1], marker="o")
    plt.xticks(rotation=45)
    xticklabels = plt.gca().get_xticklabels()
    xticklabels = [label.get_text().replace("Bottleneck", "B").replace(".layer", "L") for label in xticklabels]
    plt.xticks(ticks=range(len(xticklabels)), labels=xticklabels, rotation=45)
    plt.title("Test R2")

    plt.tight_layout()
    plt.suptitle(f"{subject_id} {modelname} layer sweep")
    saveallforms(figdir, f"{subject_id}_{modelname}_layer_sweep_GridCV_synopisis")
    plt.show()
# Out:
# All stimulus files were found
# Loading data from /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/vvs-accentuate-day1_normalize_paul_241119-241122.h5
# Fitting models for subject paul_20241119-20241122 with resnet50_robust model | 64 channels
# /n/home12/binxuwang/.conda/envs/torch2/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /n/home12/binxuwang/.conda/envs/torch2/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# The (227, 227) setting is overwritten by the size in custom transform
# ['.layer4.Bottleneck0', '.layer4.Bottleneck1', '.layer4.Bottleneck2']
#   0%|          | 0/11 [00:00<?, ?it/s]
# .layer4.Bottleneck0 torch.Size([1028, 2048, 7, 7])
# .layer4.Bottleneck1 torch.Size([1028, 2048, 7, 7])
# .layer4.Bottleneck2 torch.Size([1028, 2048, 7, 7])
# FeatureFetcher hooks all freed
# Fitting models for reliable channels > None N=64
# .layer4.Bottleneck0 torch.Size([1028, 2048, 7, 7])
# .layer4.Bottleneck1 torch.Size([1028, 2048, 7, 7])
# .layer4.Bottleneck2 torch.Size([1028, 2048, 7, 7])
# .layer4.Bottleneck0_srp RidgeCV D2_train: 0.475 D2_test: 0.144
# .layer4.Bottleneck0_pca1000 RidgeCV D2_train: 0.493 D2_test: 0.164
# .layer4.Bottleneck1_srp RidgeCV D2_train: 0.442 D2_test: 0.148
# .layer4.Bottleneck1_pca1000 RidgeCV D2_train: 0.503 D2_test: 0.161
# .layer4.Bottleneck2_srp RidgeCV D2_train: 0.393 D2_test: 0.152
# .layer4.Bottleneck2_pca1000 RidgeCV D2_train: 0.430 D2_test: 0.158
#                                                                                  alpha  \
# .layer4.Bottleneck0_srp     RidgeCV  [10000.0, 10000.0, 1000000.0, 10000.0, 100000....
# .layer4.Bottleneck0_pca1000 RidgeCV  [10000.0, 10000.0, 100000.0, 10000.0, 100000.0...
# .layer4.Bottleneck1_srp     RidgeCV  [10000.0, 10000.0, 100000.0, 10000.0, 100000.0...
# .layer4.Bottleneck1_pca1000 RidgeCV  [10000.0, 10000.0, 100000.0, 10000.0, 100000.0...
# .layer4.Bottleneck2_srp     RidgeCV  [100000.0, 100000.0, 1000000.0, 100000.0, 1000...
# .layer4.Bottleneck2_pca1000 RidgeCV  [10000.0, 100000.0, 1000000.0, 100000.0, 10000...
#
#                                     train_score test_score n_feat
# .layer4.Bottleneck0_srp     RidgeCV    0.474555    0.14421   5944
# .layer4.Bottleneck0_pca1000 RidgeCV    0.493349   0.163932   1000
# .layer4.Bottleneck1_srp     RidgeCV    0.441853   0.148078   5944
# .layer4.Bottleneck1_pca1000 RidgeCV    0.502595   0.160563   1000
# .layer4.Bottleneck2_srp     RidgeCV    0.392761   0.151994   5944
# .layer4.Bottleneck2_pca1000 RidgeCV    0.430186   0.157556   1000

# %%
dataroot = r"/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation"
stimroot = join(dataroot, "Stimuli", "shared1000") #/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/Stimuli/shared1000
pilot_MACO_root = join(dataroot, "Stimuli", "stimuli_pilot_20241119", "results")
data_path = join(dataroot, "vvs-accentuate-day1_normalize_paul_241119-241122.h5")
subject_id = 'paul_20241119-20241122'
PCA_subject_id = 'paul_20241119'
batch_size = 96 
device = "cuda" 
reliability_thresh = None
# Load data
data_dict = load_neural_data(data_path, subject_id, stimroot)
stim_names = data_dict['stimulus_names']
image_fps = parse_image_fullpaths(stim_names, [stimroot, pilot_MACO_root])
resp_mat = data_dict['resp_mat']
reliability = data_dict['reliability']
ncsnr = data_dict['ncsnr']
print(f"Loading data from {data_path}")
figroot = join(dataroot, "model_outputs")
figdir = join(dataroot, "model_outputs", subject_id, )
os.makedirs(figdir, exist_ok=True)
for modelname in ["resnet50", ]: # "resnet50_clip", "resnet50_dino", "resnet50", 
    print(f"Fitting models for subject {subject_id} with {modelname} model | {len(ncsnr)} channels")
    model, transforms_pipeline = load_model_transform(modelname, device=device)
    # Prepare dataset
    dataset = ImagePathDataset(image_fps, scores=resp_mat, transform=transforms_pipeline)

    batch_size = 96
    fetcher = featureFetcher(model, input_size=(3, 224, 224), print_module=False)
    
    module_names = [name for name in fetcher.module_names.values() if "Bottleneck" in name and ("layer4" in name )] # or "layer3" in name
    print(module_names)
    for name in module_names: 
        fetcher.record(name, store_device='cpu', ingraph=False, )
    feat_dict_lyrswp = record_features(model, fetcher, dataset, batch_size=batch_size, device=device)
    fetcher.cleanup()

    thresh = reliability_thresh
    if thresh is None:
        chan_mask = np.ones(len(ncsnr), dtype=bool)
    else:
        chan_mask = reliability > thresh
    resp_mat_sel = resp_mat[:, chan_mask]
    print(f"Fitting models for reliable channels > {thresh} N={chan_mask.sum()}")
    if os.path.exists(join(figroot, PCA_subject_id, f"{PCA_subject_id}_{modelname}_sweep_regressors_highreliab_layers_Xtfmer_RidgeCV.pkl")):
        Xtfmer_lyrswp_RidgeCV = th.load(join(figroot, PCA_subject_id, f"{PCA_subject_id}_{modelname}_sweep_regressors_highreliab_layers_Xtfmer_RidgeCV.pkl"), )
    else:
        Xtfmer_lyrswp_RidgeCV = {}
    result_df_lyrswp_RidgeCV, fit_models_lyrswp_RidgeCV, Xdict_lyrswp_RidgeCV, Xtfmer_lyrswp_RidgeCV = perform_regression_sweeplayer_RidgeCV(feat_dict_lyrswp, resp_mat_sel, 
                                                                            layer_names=module_names, dimred_list=["srp", "pca1000"], 
                                                                        alpha_list=[1E-4, 1E-3, 1E-2, 1E-1, 1, 10, 100, 1E3, 1E4, 1E5, 1E6, 1E7, 1E8, 1E9],
                                                                        verbose=True, pretrained_Xtransforms=Xtfmer_lyrswp_RidgeCV)
    result_df_lyrswp_RidgeCV.to_csv(join(figdir, f"{subject_id}_{modelname}_sweep_regressors_highreliab_layers_sweep_RidgeCV.csv"))
    th.save(fit_models_lyrswp_RidgeCV, join(figdir, f"{subject_id}_{modelname}_sweep_regressors_highreliab_layers_fitmodels_RidgeCV.pth")) 
    th.save(Xtfmer_lyrswp_RidgeCV, join(figdir, f"{subject_id}_{modelname}_sweep_regressors_highreliab_layers_Xtfmer_RidgeCV.pkl"))
    
    # summarize prediction and evaluation
    pred_dict = {}
    D2_per_unit_train_dict = {}
    D2_per_unit_test_dict = {}
    D2_per_unit_dict = {}
    for (model_dimred, regressor) in fit_models_lyrswp_RidgeCV.keys():
        fit_model = fit_models_lyrswp_RidgeCV[(model_dimred, regressor)]
        Xfeat = Xdict_lyrswp_RidgeCV[(model_dimred)]
        # Xfeat_tfmer = Xtfmer_lyrswp_RidgeCV[(model_dimred)]
        rspavg_pred = fit_model.predict(Xfeat)
        pred_dict[(model_dimred, regressor)] = rspavg_pred
        D2_per_unit = compute_D2_per_unit(resp_mat_sel, rspavg_pred)
        D2_per_unit_train = compute_D2_per_unit(resp_mat_sel[idx_train], rspavg_pred[idx_train])
        D2_per_unit_test = compute_D2_per_unit(resp_mat_sel[idx_test], rspavg_pred[idx_test])
        D2_per_unit_train_dict[(model_dimred, regressor)] = D2_per_unit_train
        D2_per_unit_test_dict[(model_dimred, regressor)] = D2_per_unit_test

    pkl.dump({
        "pred_dict": pred_dict,
        "D2_per_unit_dict": D2_per_unit_dict,
        "D2_per_unit_train_dict": D2_per_unit_train_dict,
        "D2_per_unit_test_dict": D2_per_unit_test_dict,
    }, open(join(figdir, f"{subject_id}_{modelname}_sweep_regressors_layers_pred_meta.pkl"), "wb"))

    figh, axs = plt.subplots(3, 2, figsize=(8, 12))
    for (model_dimred, regressor), ax in zip(D2_per_unit_test_dict.keys(), axs.flatten()):
        plt.sca(ax)
        plt.scatter(ncsnr, D2_per_unit_test_dict[(model_dimred, regressor)], label="test", marker="o", alpha=0.5)
        plt.scatter(ncsnr, D2_per_unit_train_dict[(model_dimred, regressor)], label="train", marker="x", alpha=0.5)
        plt.ylim(None, 1.05)
        plt.xlabel("ncsnr")
        plt.legend()
        plt.ylabel("D2 per unit")
        plt.title(f"{model_dimred}\n{regressor} D2 per unit\n[test avg {D2_per_unit_test_dict[(model_dimred, regressor)].mean():.2f} train avg {D2_per_unit_train_dict[(model_dimred, regressor)].mean():.2f}]")
    plt.suptitle(f"{subject_id} {modelname} layer sweep [train and test splits]")
    plt.tight_layout()
    saveallforms(figdir, f"{subject_id}_{modelname}_layer_sweep_GridCV_synopisis_D2perunit_ncsnr_scatter")
    plt.show()
    
    
    # for half the layers (later half) ~ 20 mins
    result_df_lyrswp_formatted = result_df_lyrswp_RidgeCV.reset_index()
    result_df_lyrswp_formatted.rename(columns={"level_0": "layer_dimred", "level_1": "regressor", }, inplace=True)
    result_df_lyrswp_formatted["layer"] = result_df_lyrswp_formatted["layer_dimred"].apply(lambda x: x.split("_")[0])
    result_df_lyrswp_formatted["dimred"] = result_df_lyrswp_formatted["layer_dimred"].apply(lambda x: x.split("_")[-1])
    result_df_lyrswp_formatted.to_csv(join(figdir, f"{subject_id}_{modelname}_sweep_regressors_highreliab_layers_sweep_RidgeCV_formatted.csv"))
    
    figh, axs = plt.subplots(1, 2, figsize=(10, 5))
    plt.sca(axs[0])
    sns.lineplot(data=result_df_lyrswp_formatted, x="layer", 
            y="train_score", style="regressor", hue="dimred", ax=axs[0], marker="o")
    plt.xticks(rotation=45)
    xticklabels = plt.gca().get_xticklabels()
    xticklabels = [label.get_text().replace("Bottleneck", "B").replace(".layer", "L") for label in xticklabels]
    plt.xticks(ticks=range(len(xticklabels)), labels=xticklabels, rotation=45)
    plt.title("Training R2")

    plt.sca(axs[1])
    sns.lineplot(data=result_df_lyrswp_formatted, x="layer", 
            y="test_score", style="regressor", hue="dimred", ax=axs[1], marker="o")
    plt.xticks(rotation=45)
    xticklabels = plt.gca().get_xticklabels()
    xticklabels = [label.get_text().replace("Bottleneck", "B").replace(".layer", "L") for label in xticklabels]
    plt.xticks(ticks=range(len(xticklabels)), labels=xticklabels, rotation=45)
    plt.title("Test R2")

    plt.tight_layout()
    plt.suptitle(f"{subject_id} {modelname} layer sweep")
    saveallforms(figdir, f"{subject_id}_{modelname}_layer_sweep_GridCV_synopisis")
    plt.show()
# Out:
# All stimulus files were found
# Loading data from /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/vvs-accentuate-day1_normalize_paul_241119-241122.h5
# Fitting models for subject paul_20241119-20241122 with resnet50 model | 64 channels
# /n/home12/binxuwang/.conda/envs/torch2/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /n/home12/binxuwang/.conda/envs/torch2/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# The (227, 227) setting is overwritten by the size in custom transform
# ['.layer4.Bottleneck0', '.layer4.Bottleneck1', '.layer4.Bottleneck2']
#   0%|          | 0/11 [00:00<?, ?it/s]
# .layer4.Bottleneck0 torch.Size([1028, 2048, 7, 7])
# .layer4.Bottleneck1 torch.Size([1028, 2048, 7, 7])
# .layer4.Bottleneck2 torch.Size([1028, 2048, 7, 7])
# FeatureFetcher hooks all freed
# Fitting models for reliable channels > None N=64
# .layer4.Bottleneck0 torch.Size([1028, 2048, 7, 7])
# .layer4.Bottleneck1 torch.Size([1028, 2048, 7, 7])
# .layer4.Bottleneck2 torch.Size([1028, 2048, 7, 7])
# .layer4.Bottleneck0_srp RidgeCV D2_train: 0.490 D2_test: 0.150
# .layer4.Bottleneck0_pca1000 RidgeCV D2_train: 0.544 D2_test: 0.162
# .layer4.Bottleneck1_srp RidgeCV D2_train: 0.464 D2_test: 0.143
# .layer4.Bottleneck1_pca1000 RidgeCV D2_train: 0.513 D2_test: 0.152
# .layer4.Bottleneck2_srp RidgeCV D2_train: 0.391 D2_test: 0.129
# .layer4.Bottleneck2_pca1000 RidgeCV D2_train: 0.401 D2_test: 0.135
#                                                                                  alpha  \
# .layer4.Bottleneck0_srp     RidgeCV  [10000.0, 10000.0, 100000.0, 10000.0, 10000.0,...
# .layer4.Bottleneck0_pca1000 RidgeCV  [1000.0, 10000.0, 1000000.0, 10000.0, 10000.0,...
# .layer4.Bottleneck1_srp     RidgeCV  [10000.0, 10000.0, 1000000000.0, 10000.0, 1000...
# .layer4.Bottleneck1_pca1000 RidgeCV  [10000.0, 10000.0, 1000000000.0, 10000.0, 1000...
# .layer4.Bottleneck2_srp     RidgeCV  [100000.0, 100000.0, 100000000.0, 100000.0, 10...
# .layer4.Bottleneck2_pca1000 RidgeCV  [100000.0, 100000.0, 1000000000.0, 100000.0, 1...
#
#                                     train_score test_score n_feat
# .layer4.Bottleneck0_srp     RidgeCV    0.489915    0.15001   5944
# .layer4.Bottleneck0_pca1000 RidgeCV    0.544178   0.162316   1000
# .layer4.Bottleneck1_srp     RidgeCV    0.464156   0.142629   5944
# .layer4.Bottleneck1_pca1000 RidgeCV    0.513423   0.152039   1000
# .layer4.Bottleneck2_srp     RidgeCV    0.391004   0.128974   5944
# .layer4.Bottleneck2_pca1000 RidgeCV    0.401278   0.134809   1000

# %% [markdown]
# ### Democratics R2 and Layer selection

# %%
modelname1 = "resnet50_robust"
modelname2 = "resnet50"
pred_meta1 = pkl.load(open(join(figdir, f"{subject_id}_{modelname1}_sweep_regressors_layers_pred_meta.pkl"), "rb"))
pred_meta2 = pkl.load(open(join(figdir, f"{subject_id}_{modelname2}_sweep_regressors_layers_pred_meta.pkl"), "rb"))

target_key1 = ('.layer4.Bottleneck1_pca1000', 'RidgeCV')
target_key2 = ('.layer4.Bottleneck1_pca1000', 'RidgeCV')
D2_per_unit_test_dict1 = pred_meta1["D2_per_unit_test_dict"][target_key1]
D2_per_unit_test_dict2 = pred_meta2["D2_per_unit_test_dict"][target_key2]
fig, ax = plt.subplots(1, 1, figsize=(5, 5))
plt.sca(ax)
plt.scatter(D2_per_unit_test_dict1, D2_per_unit_test_dict2, alpha=0.5)
plt.xlabel(f"D2 per unit ({modelname1})")
plt.ylabel(f"D2 per unit ({modelname2})")
# Out:
# Text(0, 0.5, 'D2 per unit (resnet50)')

# %%
# top 5 indices
top5_idx1 = np.argsort(D2_per_unit_test_dict1)[-5:][::-1]
print(modelname1, top5_idx1, D2_per_unit_test_dict1[top5_idx1].mean(), D2_per_unit_test_dict1[top5_idx1])
top5_idx2 = np.argsort(D2_per_unit_test_dict2)[-5:][::-1]
print(modelname2, top5_idx2, D2_per_unit_test_dict2[top5_idx2].mean(), D2_per_unit_test_dict2[top5_idx2])
assert set(top5_idx1) == set(top5_idx2)
# Out:
# resnet50_robust [40  8 25 36 47] 0.507037939662701 [0.54954231 0.53463111 0.49814485 0.48683062 0.46604081]
# resnet50 [ 8 40 47 36 25] 0.5031477359053274 [0.54431758 0.54160451 0.49205645 0.48846041 0.44929973]

# %%
# top 5 indices
topk = 5
top5_idx1 = np.argsort(D2_per_unit_test_dict1)[-topk:]
print(modelname1, target_key1, top5_idx1, D2_per_unit_test_dict1[top5_idx1].mean(), D2_per_unit_test_dict1[top5_idx1])
top5_idx2 = np.argsort(D2_per_unit_test_dict2)[-topk:]
print(modelname2, target_key2, top5_idx2, D2_per_unit_test_dict2[top5_idx2].mean(), D2_per_unit_test_dict2[top5_idx2])
assert set(top5_idx1) == set(top5_idx2)
# Out:
# resnet50_robust ('.layer4.Bottleneck1_pca1000', 'RidgeCV') [47 36 25  8 40] 0.5070379396627012 [0.46604081 0.48683062 0.49814485 0.53463111 0.54954231]
# resnet50 ('.layer4.Bottleneck1_pca1000', 'RidgeCV') [25 36 47 40  8] 0.5031477359053274 [0.44929973 0.48846041 0.49205645 0.54160451 0.54431758]

# %%
figdir
# Out:
# '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/model_outputs/paul_20241119-20241122'

# %% [markdown]
# ### Export models

# %%
# !ls /n/holylabs/LABS/kempner_fellows/Lab/neural_regress_weights_BW/paul_20241119-20241122
# Out:
# paul_20241119  paul_20241119-20241122

# %%
outputdir = f"/n/holylabs/LABS/kempner_fellows/Lab/neural_regress_weights_BW/{subject_id}"
os.makedirs(outputdir, exist_ok=True)

# %%
for modelname in ["resnet50_robust", "resnet50"]:
    fit_models_lyrswp_RidgeCV = th.load(join(figdir, f"{subject_id}_{modelname}_sweep_regressors_highreliab_layers_fitmodels_RidgeCV.pth"))
    Xtfmer_lyrswp_RidgeCV = th.load(open(join(figdir, f"{subject_id}_{modelname}_sweep_regressors_highreliab_layers_Xtfmer_RidgeCV.pkl"), "rb"))
    result_df_lyrswp_RidgeCV = pd.read_csv(join(figdir, f"{subject_id}_{modelname}_sweep_regressors_highreliab_layers_sweep_RidgeCV.csv"))
    pred_data = pkl.load(open(join(figdir, f"{subject_id}_{modelname}_sweep_regressors_layers_pred_meta.pkl"), "rb"))

    key = ('.layer4.Bottleneck1_pca1000', 'RidgeCV')
    readout_path = join(outputdir, f"{subject_id}_{modelname}_sweep_regressors_readout_RidgeCV_{key[0]}.pth")
    Xtransform_path = join(outputdir, f"{subject_id}_{modelname}_sweep_regressors_Xtfmer_RidgeCV_{key[0]}.pkl")
    meta_path = join(outputdir, f"{subject_id}_{modelname}_sweep_regressors_meta_RidgeCV_{key[0]}.pkl")

    regressor = fit_models_lyrswp_RidgeCV[key]
    Xtfmer = Xtfmer_lyrswp_RidgeCV[key[0]]
    pred_rsp = pred_data["pred_dict"][key]
    D2_per_unit_test = pred_data["D2_per_unit_test_dict"][key]
    D2_per_unit_train = pred_data["D2_per_unit_train_dict"][key]

    readout = LinearLayer_from_sklearn(regressor)
    th.save(readout.state_dict(), readout_path)
    pkl.dump(Xtfmer, open(Xtransform_path, "wb"))
    th.save({
        "reliability": reliability,
        "ncsnr": ncsnr,
        "D2_per_unit_test": D2_per_unit_test,
        "D2_per_unit_train": D2_per_unit_train
    }, meta_path)
    print(f"Saved {readout_path}")
    print(f"Saved {Xtransform_path}")
    print(f"Saved {meta_path}")
# Out:
# Saved /n/holylabs/LABS/kempner_fellows/Lab/neural_regress_weights_BW/paul_20241119-20241122/paul_20241119-20241122_resnet50_robust_sweep_regressors_readout_RidgeCV_.layer4.Bottleneck1_pca1000.pth
# Saved /n/holylabs/LABS/kempner_fellows/Lab/neural_regress_weights_BW/paul_20241119-20241122/paul_20241119-20241122_resnet50_robust_sweep_regressors_Xtfmer_RidgeCV_.layer4.Bottleneck1_pca1000.pkl
# Saved /n/holylabs/LABS/kempner_fellows/Lab/neural_regress_weights_BW/paul_20241119-20241122/paul_20241119-20241122_resnet50_robust_sweep_regressors_meta_RidgeCV_.layer4.Bottleneck1_pca1000.pkl
# Saved /n/holylabs/LABS/kempner_fellows/Lab/neural_regress_weights_BW/paul_20241119-20241122/paul_20241119-20241122_resnet50_sweep_regressors_readout_RidgeCV_.layer4.Bottleneck1_pca1000.pth
# Saved /n/holylabs/LABS/kempner_fellows/Lab/neural_regress_weights_BW/paul_20241119-20241122/paul_20241119-20241122_resnet50_sweep_regressors_Xtfmer_RidgeCV_.layer4.Bottleneck1_pca1000.pkl
# Saved /n/holylabs/LABS/kempner_fellows/Lab/neural_regress_weights_BW/paul_20241119-20241122/paul_20241119-20241122_resnet50_sweep_regressors_meta_RidgeCV_.layer4.Bottleneck1_pca1000.pkl

# %% [markdown]
# ### Neural pixel array fitting

# %%
dataroot = r"/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation"
stimroot = join(dataroot, "shared1000")
data_path = join(dataroot, "vvs-accentuate-day1_normalize_paul_241119.h5")
subject_id = 'paul_241119'
batch_size = 96 
device = "cuda" 
reliability_thresh = None
# Load data
data_dict = load_neural_data(data_path, subject_id, stimroot)
image_fps = data_dict['image_fps']
resp_mat = data_dict['resp_mat']
reliability = data_dict['reliability']
ncsnr = data_dict['ncsnr']
print(f"Loading data from {data_path}")
figdir = join(dataroot, "model_outputs", subject_id, )
os.makedirs(figdir, exist_ok=True)
idx_train, idx_test = train_test_split(
    np.arange(len(resp_mat)), test_size=0.2, random_state=42, shuffle=True
)
for modelname in ["resnet50_robust", "resnet50", "resnet50_clip", "resnet50_dino", ]: # 
    print(f"Fitting models for subject {subject_id} with {modelname} model | {len(ncsnr)} channels")
    model, transforms_pipeline = load_model_transform(modelname, device=device)
    # Prepare dataset
    dataset = ImagePathDataset(image_fps, scores=resp_mat, transform=transforms_pipeline)

    batch_size = 96
    fetcher = featureFetcher(model, input_size=(3, 224, 224), print_module=False)
    
    module_names = [name for name in fetcher.module_names.values() if "Bottleneck" in name and ("layer4" in name )] # or "layer3" in name
    print(module_names)
    for name in module_names: 
        fetcher.record(name, store_device='cpu', ingraph=False, )
    feat_dict_lyrswp = record_features(model, fetcher, dataset, batch_size=batch_size, device=device)
    fetcher.cleanup()

    thresh = reliability_thresh
    if thresh is None:
        chan_mask = np.ones(len(ncsnr), dtype=bool)
    else:
        chan_mask = reliability > thresh
    resp_mat_sel = resp_mat[:, chan_mask]
    print(f"Fitting models for reliable channels > {thresh} N={chan_mask.sum()}")
    if os.path.exists(join(figdir, f"{subject_id}_{modelname}_sweep_regressors_highreliab_layers_Xtfmer_RidgeCV.pkl")):
        Xtfmer_lyrswp_RidgeCV = th.load(join(figdir, f"{subject_id}_{modelname}_sweep_regressors_highreliab_layers_Xtfmer_RidgeCV.pkl"), )
    else:
        Xtfmer_lyrswp_RidgeCV = {}
    result_df_lyrswp_RidgeCV, fit_models_lyrswp_RidgeCV, Xdict_lyrswp_RidgeCV, Xtfmer_lyrswp_RidgeCV = perform_regression_sweeplayer_RidgeCV(feat_dict_lyrswp, resp_mat_sel, 
                                                                            layer_names=module_names, dimred_list=["srp", "pca1000"], 
                                                                        alpha_list=[1E-4, 1E-3, 1E-2, 1E-1, 1, 10, 100, 1E3, 1E4, 1E5, 1E6, 1E7, 1E8, 1E9],
                                                                        verbose=True, pretrained_Xtransforms=Xtfmer_lyrswp_RidgeCV)
    result_df_lyrswp_RidgeCV.to_csv(join(figdir, f"{subject_id}_{modelname}_sweep_regressors_highreliab_layers_sweep_RidgeCV.csv"))
    th.save(fit_models_lyrswp_RidgeCV, join(figdir, f"{subject_id}_{modelname}_sweep_regressors_highreliab_layers_fitmodels_RidgeCV.pth")) 
    th.save(Xtfmer_lyrswp_RidgeCV, join(figdir, f"{subject_id}_{modelname}_sweep_regressors_highreliab_layers_Xtfmer_RidgeCV.pkl"))
    
    # summarize prediction and evaluation
    pred_dict = {}
    D2_per_unit_train_dict = {}
    D2_per_unit_test_dict = {}
    D2_per_unit_dict = {}
    for (model_dimred, regressor) in fit_models_lyrswp_RidgeCV.keys():
        fit_model = fit_models_lyrswp_RidgeCV[(model_dimred, regressor)]
        Xfeat = Xdict_lyrswp_RidgeCV[(model_dimred)]
        # Xfeat_tfmer = Xtfmer_lyrswp_RidgeCV[(model_dimred)]
        rspavg_pred = fit_model.predict(Xfeat)
        pred_dict[(model_dimred, regressor)] = rspavg_pred
        D2_per_unit = compute_D2_per_unit(resp_mat_sel, rspavg_pred)
        D2_per_unit_train = compute_D2_per_unit(resp_mat_sel[idx_train], rspavg_pred[idx_train])
        D2_per_unit_test = compute_D2_per_unit(resp_mat_sel[idx_test], rspavg_pred[idx_test])
        D2_per_unit_train_dict[(model_dimred, regressor)] = D2_per_unit_train
        D2_per_unit_test_dict[(model_dimred, regressor)] = D2_per_unit_test

    pkl.dump({
        "pred_dict": pred_dict,
        "D2_per_unit_dict": D2_per_unit_dict,
        "D2_per_unit_train_dict": D2_per_unit_train_dict,
        "D2_per_unit_test_dict": D2_per_unit_test_dict,
    }, open(join(figdir, f"{subject_id}_{modelname}_sweep_regressors_layers_pred_meta.pkl"), "wb"))

    figh, axs = plt.subplots(3, 2, figsize=(8, 12))
    for (model_dimred, regressor), ax in zip(D2_per_unit_test_dict.keys(), axs.flatten()):
        plt.sca(ax)
        plt.scatter(ncsnr, D2_per_unit_test_dict[(model_dimred, regressor)], label="test", marker="o", alpha=0.5)
        plt.scatter(ncsnr, D2_per_unit_train_dict[(model_dimred, regressor)], label="train", marker="x", alpha=0.5)
        plt.ylim(None, 1.05)
        plt.xlabel("ncsnr")
        plt.legend()
        plt.ylabel("D2 per unit")
        plt.title(f"{model_dimred}\n{regressor} D2 per unit\n[test avg {D2_per_unit_test_dict[(model_dimred, regressor)].mean():.2f} train avg {D2_per_unit_train_dict[(model_dimred, regressor)].mean():.2f}]")
    plt.suptitle(f"{subject_id} {modelname} layer sweep [train and test splits]")
    plt.tight_layout()
    saveallforms(figdir, f"{subject_id}_{modelname}_layer_sweep_GridCV_synopisis_D2perunit_ncsnr_scatter")
    plt.show()
    
    
    # for half the layers (later half) ~ 20 mins
    result_df_lyrswp_formatted = result_df_lyrswp_RidgeCV.reset_index()
    result_df_lyrswp_formatted.rename(columns={"level_0": "layer_dimred", "level_1": "regressor", }, inplace=True)
    result_df_lyrswp_formatted["layer"] = result_df_lyrswp_formatted["layer_dimred"].apply(lambda x: x.split("_")[0])
    result_df_lyrswp_formatted["dimred"] = result_df_lyrswp_formatted["layer_dimred"].apply(lambda x: x.split("_")[-1])
    result_df_lyrswp_formatted.to_csv(join(figdir, f"{subject_id}_{modelname}_sweep_regressors_highreliab_layers_sweep_RidgeCV_formatted.csv"))


    figh, axs = plt.subplots(1, 2, figsize=(10, 5))
    plt.sca(axs[0])
    sns.lineplot(data=result_df_lyrswp_formatted, x="layer", 
            y="train_score", style="regressor", hue="dimred", ax=axs[0], marker="o")
    plt.xticks(rotation=45)
    xticklabels = plt.gca().get_xticklabels()
    xticklabels = [label.get_text().replace("Bottleneck", "B").replace(".layer", "L") for label in xticklabels]
    plt.xticks(ticks=range(len(xticklabels)), labels=xticklabels, rotation=45)
    plt.title("Training R2")

    plt.sca(axs[1])
    sns.lineplot(data=result_df_lyrswp_formatted, x="layer", 
            y="test_score", style="regressor", hue="dimred", ax=axs[1], marker="o")
    plt.xticks(rotation=45)
    xticklabels = plt.gca().get_xticklabels()
    xticklabels = [label.get_text().replace("Bottleneck", "B").replace(".layer", "L") for label in xticklabels]
    plt.xticks(ticks=range(len(xticklabels)), labels=xticklabels, rotation=45)
    plt.title("Test R2")

    plt.tight_layout()
    plt.suptitle(f"{subject_id} {modelname} layer sweep")
    saveallforms(figdir, f"{subject_id}_{modelname}_layer_sweep_GridCV_synopisis")
    plt.show()
# Out:
# Loading data from /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/vvs-accentuate-day1_normalize_paul_241119.h5
# Fitting models for subject paul_241119 with resnet50_robust model | 383 channels
# /n/home12/binxuwang/.conda/envs/torch2/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /n/home12/binxuwang/.conda/envs/torch2/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# The (227, 227) setting is overwritten by the size in custom transform
# ['.layer4.Bottleneck0', '.layer4.Bottleneck1', '.layer4.Bottleneck2']
#   0%|          | 0/11 [00:00<?, ?it/s]
# .layer4.Bottleneck0 torch.Size([1028, 2048, 7, 7])
# .layer4.Bottleneck1 torch.Size([1028, 2048, 7, 7])
# .layer4.Bottleneck2 torch.Size([1028, 2048, 7, 7])
# FeatureFetcher hooks all freed
# Fitting models for reliable channels > None N=383
# .layer4.Bottleneck0 torch.Size([1028, 2048, 7, 7])
# .layer4.Bottleneck1 torch.Size([1028, 2048, 7, 7])
# .layer4.Bottleneck2 torch.Size([1028, 2048, 7, 7])
# .layer4.Bottleneck0_srp RidgeCV D2_train: 0.075 D2_test: 0.001
# .layer4.Bottleneck0_pca1000 RidgeCV D2_train: 0.080 D2_test: 0.002
# .layer4.Bottleneck1_srp RidgeCV D2_train: 0.072 D2_test: 0.001
# .layer4.Bottleneck1_pca1000 RidgeCV D2_train: 0.076 D2_test: 0.001
# .layer4.Bottleneck2_srp RidgeCV D2_train: 0.065 D2_test: 0.001
# .layer4.Bottleneck2_pca1000 RidgeCV D2_train: 0.068 D2_test: 0.001
#                                                                                  alpha  \
# .layer4.Bottleneck0_srp     RidgeCV  [1000000000.0, 1000000000.0, 1000000.0, 100000...
# .layer4.Bottleneck0_pca1000 RidgeCV  [1000000000.0, 1000000000.0, 1000000.0, 100000...
# .layer4.Bottleneck1_srp     RidgeCV  [1000000000.0, 1000000000.0, 1000000.0, 100000...
# .layer4.Bottleneck1_pca1000 RidgeCV  [1000000000.0, 1000000000.0, 1000000.0, 100000...
# .layer4.Bottleneck2_srp     RidgeCV  [1000000000.0, 1000000000.0, 1000000.0, 100000...
# .layer4.Bottleneck2_pca1000 RidgeCV  [10000000.0, 1000000000.0, 1000000.0, 10000000...
#
#                                     train_score test_score n_feat
# .layer4.Bottleneck0_srp     RidgeCV    0.074739   0.001362   5944
# .layer4.Bottleneck0_pca1000 RidgeCV    0.079548   0.001994   1000
# .layer4.Bottleneck1_srp     RidgeCV    0.071858   0.001382   5944
# .layer4.Bottleneck1_pca1000 RidgeCV    0.076392   0.001285   1000
# .layer4.Bottleneck2_srp     RidgeCV    0.065432   0.000794   5944
# .layer4.Bottleneck2_pca1000 RidgeCV    0.067812   0.001385   1000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 63
#      61 rspavg_pred = fit_model.predict(Xfeat)
#      62 pred_dict[(model_dimred, regressor)] = rspavg_pred
# ---> 63 D2_per_unit = compute_D2_per_unit(rspavg_resp_peak, rspavg_pred)
#      64 D2_per_unit_train = compute_D2_per_unit(rspavg_resp_peak[idx_train], rspavg_pred[idx_train])
#      65 D2_per_unit_test = compute_D2_per_unit(rspavg_resp_peak[idx_test], rspavg_pred[idx_test])
#
# Cell In[39], line 3, in compute_D2_per_unit(rspavg_resp_peak, rspavg_pred)
#       2 def compute_D2_per_unit(rspavg_resp_peak, rspavg_pred):
# ----> 3     return 1 - np.square(rspavg_resp_peak - rspavg_pred).sum(axis=0) / np.square(rspavg_resp_peak - rspavg_resp_peak.mean(axis=0)).sum(axis=0)
#
# ValueError: operands could not be broadcast together with shapes (1028,64) (1028,383)

# %% [markdown]
# ### Evaluate the fits separately

# %%
rspavg_pred
# Out:
# array([[0.46502571, 0.530665  , 0.48078774, ..., 0.63191901, 0.29132967,
#         0.49452008],
#        [0.57262446, 0.47385085, 0.47955196, ..., 0.54764787, 0.3751547 ,
#         0.51015929],
#        [0.60387989, 0.66790043, 0.48071936, ..., 0.53858882, 0.40156122,
#         0.49245193],
#        ...,
#        [1.62651854, 0.84501692, 0.47962383, ..., 0.41660494, 0.6354187 ,
#         0.5789594 ],
#        [1.66385962, 1.25584118, 0.48505274, ..., 0.3926906 , 0.7912529 ,
#         0.55886755],
#        [2.2149652 , 0.99234585, 0.49847044, ..., 0.45830786, 0.69148003,
#         0.51728337]])

# %%
pred_dict = {}
D2_per_unit_train_dict = {}
D2_per_unit_test_dict = {}
for (model_dimred, regressor) in fit_models_lyrswp_RidgeCV.keys():
    fit_model = fit_models_lyrswp_RidgeCV[(model_dimred, regressor)]
    Xfeat = Xdict_lyrswp_RidgeCV[(model_dimred)]
    # Xfeat_tfmer = Xtfmer_lyrswp_RidgeCV[(model_dimred)]
    rspavg_pred = fit_model.predict(Xfeat)
    pred_dict[(model_dimred, regressor)] = rspavg_pred
    D2_per_unit_train = compute_D2_per_unit(rspavg_resp_peak[idx_train], rspavg_pred[idx_train])
    D2_per_unit_test = compute_D2_per_unit(rspavg_resp_peak[idx_test], rspavg_pred[idx_test])
    D2_per_unit_train_dict[(model_dimred, regressor)] = D2_per_unit_train
    D2_per_unit_test_dict[(model_dimred, regressor)] = D2_per_unit_test

pkl.dump({
    "pred_dict": pred_dict,
    "D2_per_unit_train_dict": D2_per_unit_train_dict,
    "D2_per_unit_test_dict": D2_per_unit_test_dict,
}, open(join(figdir, f"{subject_id}_{modelname}_sweep_regressors_layers_pred_meta.pkl"), "wb"))

figh, axs = plt.subplots(3, 2, figsize=(8, 12))
for (model_dimred, regressor), ax in zip(D2_per_unit_test_dict.keys(), axs.flatten()):
    plt.sca(ax)
    plt.scatter(ncsnr, D2_per_unit_test_dict[(model_dimred, regressor)], label="test", marker="o", alpha=0.5)
    plt.scatter(ncsnr, D2_per_unit_train_dict[(model_dimred, regressor)], label="train", marker="x", alpha=0.5)
    plt.ylim(None, 1.05)
    plt.xlabel("ncsnr")
    plt.legend()
    plt.ylabel("D2 per unit")
    plt.title(f"{model_dimred}\n{regressor} D2 per unit\n[test avg {D2_per_unit_test_dict[(model_dimred, regressor)].mean():.2f} train avg {D2_per_unit_train_dict[(model_dimred, regressor)].mean():.2f}]")
plt.suptitle(f"{subject_id} {modelname} layer sweep [train and test splits]")
plt.tight_layout()
saveallforms(figdir, f"{subject_id}_{modelname}_layer_sweep_GridCV_synopisis_D2perunit_ncsnr_scatter")
plt.show()

# %%
figh, axs = plt.subplots(3, 2, figsize=(8, 12))
for (model_dimred, regressor), ax in zip(D2_per_unit_test_dict.keys(), axs.flatten()):
    plt.sca(ax)
    plt.scatter(ncsnr, D2_per_unit_test_dict[(model_dimred, regressor)], label="test", marker="o", alpha=0.5)
    plt.scatter(ncsnr, D2_per_unit_train_dict[(model_dimred, regressor)], label="train", marker="x", alpha=0.5)
    plt.ylim(None, 1.05)
    plt.xlabel("ncsnr")
    plt.legend()
    plt.ylabel("D2 per unit")
    plt.title(f"{model_dimred}\n{regressor} D2 per unit\n[test avg {D2_per_unit_test_dict[(model_dimred, regressor)].mean():.2f} train avg {D2_per_unit_train_dict[(model_dimred, regressor)].mean():.2f}]")
plt.suptitle(f"{subject_id} {modelname} layer sweep [test splits only]")
plt.tight_layout()
plt.show()

# %%
figh, axs = plt.subplots(3, 2, figsize=(8, 12))
for (model_dimred, regressor), ax in zip(D2_per_unit_train_dict.keys(), axs.flatten()):
    plt.sca(ax)
    plt.scatter(ncsnr, D2_per_unit_train_dict[(model_dimred, regressor)], label="train", marker="o", alpha=0.5)
    plt.ylim(None, 1.05)
    plt.xlabel("ncsnr")
    plt.ylabel("D2 per unit")
    plt.title(f"{model_dimred}\n{regressor} D2 per unit [avg {D2_per_unit_train_dict[(model_dimred, regressor)].mean():.2f}]")
plt.suptitle(f"{subject_id} {modelname} layer sweep [train splits]")
plt.tight_layout()
plt.show()

# %%
# !cd /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation
# !for file in /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/stimuli_pilot_20241119/results/*; do
    ln -sf "$file" shared1000
done

# %%
data_dict
# Out:
# {'brain_area': array([b'l_cIT', b'l_cIT', b'l_cIT', b'l_cIT', b'l_cIT', b'l_cIT',
#         b'l_cIT', b'l_cIT', b'l_cIT', b'l_cIT', b'l_cIT', b'l_cIT',
#         b'l_cIT', b'l_cIT', b'l_cIT', b'l_cIT', b'l_cIT', b'l_cIT',
#         b'l_cIT', b'l_cIT', b'l_cIT', b'l_cIT', b'l_cIT', b'l_cIT',
#         b'l_cIT', b'l_cIT', b'l_cIT', b'l_cIT', b'l_cIT', b'l_cIT',
#         b'l_cIT', b'l_cIT', b'l_cIT', b'l_cIT', b'l_cIT', b'l_cIT',
#         b'l_cIT', b'l_cIT', b'l_cIT', b'l_cIT', b'l_cIT', b'l_cIT',
#         b'l_cIT', b'l_cIT', b'l_cIT', b'l_cIT', b'l_cIT', b'l_cIT',
#         b'l_cIT', b'l_cIT', b'l_cIT', b'l_cIT', b'l_cIT', b'l_cIT',
#         b'l_cIT', b'l_cIT', b'l_cIT', b'l_cIT', b'l_cIT', b'l_cIT',
#         b'l_cIT', b'l_cIT', b'l_cIT', b'l_cIT'], dtype=object),
#  'ncsnr': array([0.8082842 , 0.5987334 , 0.        , 0.7216381 , 0.14398432,
#         0.8402192 , 0.9996467 , 1.1090726 , 0.86786723, 0.5246871 ,
#         0.25285387, 0.40623817, 0.11611781, 0.3684164 , 0.29429722,
#         0.593332  , 0.27200845, 0.9758751 , 0.4347726 , 0.23363958,
#         0.40098363, 0.30443692, 0.88030857, 0.5970783 , 1.1920465 ,
#         0.90392894, 0.6424594 , 0.6979883 , 0.45652956, 0.34923458,
#         0.4052368 , 0.6019686 , 0.3242473 , 0.        , 0.17997177,
#         0.        , 0.8134201 , 0.171386  , 0.53538   , 0.        ,
#         1.0202495 , 0.42044708, 0.24427211, 0.16398832, 0.10164459,
#         0.        , 0.        , 1.3619682 , 0.6429623 , 0.22187302,
#         0.19339383, 0.14365914, 0.20865369, 0.        , 0.        ,
#         0.        , 0.17714503, 0.        , 0.21224234, 0.        ,
#         0.        , 0.        , 0.29601276, 0.        ], dtype=float32),
#  'reliability': array([ 0.39990534,  0.27173216, -0.01391219,  0.3429431 ,  0.01945908,
#          0.42452301,  0.49902749,  0.55766227,  0.43531724,  0.22467763,
#          0.03569183,  0.15228482,  0.00323693,  0.10299028,  0.06391021,
#          0.26208804,  0.07210981,  0.49560961,  0.16148884,  0.04403943,
#          0.14386155,  0.11693172,  0.43956004,  0.27158672,  0.58265665,
#          0.45000705,  0.29464782,  0.32774729,  0.17625075,  0.12272577,
#          0.13490958,  0.26187126,  0.09918484,  0.01969539,  0.04242806,
#         -0.04819055,  0.41203511,  0.03675573,  0.23531169, -0.29816392,
#          0.50486237,  0.14196414,  0.0612752 ,  0.02476616,  0.01372023,
#         -0.27934553, -0.05276467,  0.64959374,  0.30444041,  0.02610773,
#          0.0433119 ,  0.03275699,  0.06624898, -0.05166048, -0.01097155,
#         -0.04971659,  0.03378633, -0.02738414,  0.04543071, -0.10972002,
#         -0.0537313 , -0.00881088,  0.08237464, -0.02592653]),
#  'stim_pos': array([[0, 3],
#         [0, 3],
#         [0, 3],
#         ...,
#         [0, 3],
#         [0, 3],
#         [0, 3]], dtype=uint8),
#  'stim_size': array([[267, 267],
#         [267, 267],
#         [267, 267],
#         ...,
#         [267, 267],
#         [267, 267],
#         [267, 267]], dtype=uint16),
#  'resp_mat': array([[-9.4853753e-01,  3.3875006e-01,  2.4346437e+00, ...,
#           4.2813134e+00,  1.1569565e-03, -6.6553044e-01],
#         [ 1.5390348e-01,  1.2613642e-01, -2.0866099e-01, ...,
#           7.3775274e-01,  5.4235530e-01, -1.3399637e-01],
#         [ 1.4630520e+00,  4.4505689e-01, -3.2358730e-01, ...,
#           2.9040560e-02,  4.6504122e-01, -3.1117439e-01],
#         ...,
#         [ 3.5990319e+00,  2.0396593e+00,  8.2567561e-01, ...,
#           5.0151533e-01,  7.7429748e-01, -6.6553044e-01],
#         [ 1.3547767e+00,  2.0396593e+00,  1.1704545e+00, ...,
#          -9.1590899e-01,  1.0835537e+00,  7.5189376e-01],
#         [ 3.1659298e+00,  7.6397735e-01,  1.9749385e+00, ...,
#          -4.4343421e-01,  1.3928099e+00,  1.1062498e+00]], dtype=float32),
#  'resp_temp_mat': array([[[ 0.5594444 ,  1.7420001 , -1.7027028 , ..., -2.3333333 ,
#            0.5578181 , -2.7916667 ],
#          [-2.7321296 , -0.12899995,  2.3427024 , ..., -0.2544443 ,
#           -0.80290914, -1.2325001 ],
#          [ 5.150324  , -0.12899993, -1.7027028 , ...,  1.8244447 ,
#           -0.12254551, -2.7916667 ],
#          ...,
#          [-1.3462038 , -0.12899993,  0.31999993, ..., -2.3333333 ,
#            1.9185454 , -2.7916667 ],
#          [ 5.670046  ,  0.8065001 , -0.6913514 , ..., -0.2544443 ,
#           -1.4832728 ,  0.32666647],
#          [10.780648  , -0.12899993, -1.7027028 , ...,  5.9822226 ,
#            4.64      ,  0.32666647]],
#
#         [[ 0.5594444 ,  1.7420001 , -1.7027028 , ..., -2.3333333 ,
#           -0.80290914, -2.7916667 ],
#          [-4.1180553 ,  0.8065001 ,  1.3313513 , ..., -0.2544443 ,
#           -0.12254554, -1.2325001 ],
#          [-0.39337957, -0.12899993, -1.7027028 , ..., -0.2544443 ,
#            1.9185454 , -2.7916667 ],
#          ...,
#          [-1.3462038 , -2.        , -1.7027028 , ..., -2.3333333 ,
#           -0.80290914, -2.7916667 ],
#          [ 0.9925462 ,  0.8065001 , -0.6913514 , ..., -0.2544443 ,
#           -0.12254551,  0.32666647],
#          [ 1.425648  , -2.        , -1.7027028 , ...,  5.9822226 ,
#            3.2792726 ,  0.32666647]],
#
#         [[ 0.5594444 , -2.        ,  0.31999993, ..., -2.3333333 ,
#            0.5578181 , -2.7916667 ],
#          [-4.1180553 ,  1.7420001 ,  1.3313513 , ..., -0.2544443 ,
#            0.5578182 , -2.7916667 ],
#          [ 0.5594444 , -2.        ,  0.31999993, ...,  1.8244447 ,
#            1.2381817 , -1.2325001 ],
#          ...,
#          [-4.1180553 , -2.        ,  2.3427026 , ...,  1.8244447 ,
#           -0.80290914,  0.32666647],
#          [-4.1180553 , -1.0645    , -0.6913514 , ..., -2.3333333 ,
#           -0.12254551,  0.32666647],
#          [ 1.425648  ,  1.7420001 ,  0.31999993, ..., -2.3333333 ,
#            7.3614545 ,  0.32666647]],
#
#         ...,
#
#         [[ 0.5594444 , -0.12899993,  4.365405  , ...,  5.9822226 ,
#           -2.1636364 ,  3.4449997 ],
#          [ 1.425648  , -1.0645    , -1.7027028 , ..., -0.2544443 ,
#           -0.80290914,  1.8858331 ],
#          [-4.1180553 ,  0.8065001 , -1.7027028 , ..., -0.2544443 ,
#           -0.12254554,  1.885833  ],
#          ...,
#          [-1.3462038 , -2.        , -1.7027028 , ..., -2.3333333 ,
#            3.2792728 , -2.7916667 ],
#          [ 7.4890738 , -1.0645    , -0.6913514 , ..., -0.2544443 ,
#           -0.80290914,  1.8858331 ],
#          [-4.1180553 ,  1.7420001 ,  0.31999993, ..., -2.3333333 ,
#            0.5578181 ,  6.563333  ]],
#
#         [[-4.1180553 , -0.12899993,  4.365405  , ..., 18.455557  ,
#           -0.80290914,  3.4449997 ],
#          [ 0.03972208, -0.12899995, -0.6913514 , ..., -2.3333333 ,
#           -0.12254551, -2.7916667 ],
#          [ 0.9925463 , -0.12899995, -0.6913514 , ..., -2.3333333 ,
#           -0.80290914,  0.32666647],
#          ...,
#          [-1.3462038 , -2.        ,  0.31999993, ...,  1.8244447 ,
#            4.64      ,  0.32666647],
#          [ 2.811574  , -1.0645    , -0.6913514 , ...,  3.9033337 ,
#           -0.80290914,  0.32666647],
#          [-4.1180553 , -0.12899993,  0.31999993, ...,  5.9822226 ,
#            1.9185454 , 12.799999  ]],
#
#         [[-1.3462038 , -0.12899993,  0.31999993, ..., 10.14      ,
#           -0.80290914,  0.32666647],
#          [ 0.9925462 ,  0.8065001 ,  1.3313513 , ..., -2.3333333 ,
#            1.2381817 , -2.7916667 ],
#          [ 0.9925463 , -2.        ,  0.31999993, ..., -0.2544443 ,
#            0.5578181 ,  0.32666647],
#          ...,
#          [-1.3462038 ,  1.7420001 ,  0.31999993, ...,  1.8244447 ,
#            1.9185454 ,  0.32666647],
#          [-0.3933797 , -2.        , -0.6913514 , ...,  3.9033337 ,
#           -0.12254551, -1.2325001 ],
#          [-4.1180553 , -0.12899993,  0.31999993, ...,  5.9822226 ,
#            3.2792728 , 12.799999  ]]], dtype=float32),
#  'image_fps': ['/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_neg_0_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_neg_0_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_neg_1_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_neg_1_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_neg_2_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_neg_2_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_neg_3_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_neg_3_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_neg_4_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_neg_4_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_neg_5_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_neg_5_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_neg_6_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_neg_6_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_neg_7_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_neg_7_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_pos_0_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_pos_0_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_pos_1_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_pos_1_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_pos_2_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_pos_2_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_pos_3_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_pos_3_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_pos_4_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_pos_4_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_pos_5_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_pos_5_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_pos_6_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_pos_6_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_pos_7_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/clip_pos_7_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_neg_0_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_neg_0_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_neg_1_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_neg_1_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_neg_2_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_neg_2_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_neg_3_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_neg_3_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_neg_4_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_neg_4_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_neg_5_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_neg_5_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_neg_6_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_neg_6_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_neg_7_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_neg_7_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_pos_0_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_pos_0_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_pos_1_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_pos_1_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_pos_2_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_pos_2_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_pos_3_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_pos_3_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_pos_4_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_pos_4_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_pos_5_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_pos_5_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_pos_6_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_pos_6_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_pos_7_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/dinov1_pos_7_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_001_adult-1.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_002_adult-2.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_003_adult-3.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_004_adult-4.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_005_adult-5.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_006_adult-6.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_007_adult-7.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_008_adult-8.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_009_adult-9.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_010_adult-10.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_011_body-1.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_012_body-2.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_013_body-3.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_014_body-4.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_015_body-5.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_016_body-6.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_017_body-7.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_018_body-8.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_019_body-9.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_020_body-10.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_021_car-1.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_022_car-2.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_023_car-3.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_024_car-4.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_025_car-5.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_026_car-6.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_027_car-7.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_028_car-8.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_029_car-9.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_030_car-10.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_031_child-1.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_032_child-2.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_033_child-3.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_034_child-4.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_035_child-5.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_036_child-6.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_037_child-7.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_038_child-8.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_039_child-9.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_040_child-10.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_041_corridor-1.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_042_corridor-2.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_043_corridor-3.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_044_corridor-4.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_045_corridor-5.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_046_corridor-6.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_047_corridor-7.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_048_corridor-8.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_049_corridor-9.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_050_corridor-10.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_051_house-1.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_052_house-2.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_053_house-3.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_054_house-4.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_055_house-5.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_056_house-6.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_057_house-7.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_058_house-8.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_059_house-9.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_060_house-10.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_061_instrument-1.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_062_instrument-2.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_063_instrument-3.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_064_instrument-4.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_065_instrument-5.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_066_instrument-6.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_067_instrument-7.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_068_instrument-8.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_069_instrument-9.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_070_instrument-10.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_071_limb-1.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_072_limb-2.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_073_limb-3.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_074_limb-4.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_075_limb-5.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_076_limb-6.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_077_limb-7.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_078_limb-8.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_079_limb-9.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_080_limb-10.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_091_scrambled-1.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_092_scrambled-2.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_093_scrambled-3.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_094_scrambled-4.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_095_scrambled-5.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_096_scrambled-6.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_097_scrambled-7.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_098_scrambled-8.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_099_scrambled-9.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_100_scrambled-10.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_101_word-1.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_102_word-2.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_103_word-3.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_104_word-4.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_105_word-5.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_106_word-6.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_107_word-7.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_108_word-8.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_109_word-9.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/fLoc_subset_110_word-10.jpg',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_neg_0_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_neg_0_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_neg_1_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_neg_1_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_neg_2_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_neg_2_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_neg_3_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_neg_3_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_neg_4_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_neg_4_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_neg_5_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_neg_5_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_neg_6_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_neg_6_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_neg_7_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_neg_7_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_pos_0_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_pos_0_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_pos_1_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_pos_1_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_pos_2_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_pos_2_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_pos_3_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_pos_3_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_pos_4_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_pos_4_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_pos_5_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_pos_5_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_pos_6_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_pos_6_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_pos_7_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/r50_pos_7_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_neg_0_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_neg_0_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_neg_1_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_neg_1_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_neg_2_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_neg_2_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_neg_3_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_neg_3_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_neg_4_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_neg_4_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_neg_5_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_neg_5_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_neg_6_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_neg_6_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_neg_7_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_neg_7_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_pos_0_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_pos_0_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_pos_1_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_pos_1_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_pos_2_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_pos_2_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_pos_3_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_pos_3_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_pos_4_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_pos_4_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_pos_5_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_pos_5_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_pos_6_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_pos_6_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_pos_7_2048_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/robustr50_pos_7_512_tr.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0001_nsd02951.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0002_nsd02991.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0003_nsd03050.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0005_nsd03147.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0006_nsd03158.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0007_nsd03165.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0008_nsd03172.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0009_nsd03182.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0010_nsd03387.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0011_nsd03435.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0012_nsd03450.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0013_nsd03490.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0014_nsd03627.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0016_nsd03688.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0017_nsd03730.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0018_nsd03810.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0019_nsd03843.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0020_nsd03848.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0021_nsd03857.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0022_nsd03914.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0023_nsd03952.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0024_nsd04052.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0025_nsd04059.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0026_nsd04130.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0027_nsd04157.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0028_nsd04250.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0029_nsd04326.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0030_nsd04424.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0031_nsd04437.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0032_nsd04613.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0033_nsd04668.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0035_nsd04769.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0036_nsd04787.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0038_nsd04870.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0039_nsd04893.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0041_nsd05035.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0042_nsd05107.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0043_nsd05205.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0044_nsd05286.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0045_nsd05302.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0047_nsd05428.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0048_nsd05460.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0050_nsd05543.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0051_nsd05575.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0053_nsd05603.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0054_nsd05715.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0056_nsd05891.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0057_nsd06133.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0058_nsd06200.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0059_nsd06223.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0060_nsd06432.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0061_nsd06445.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0062_nsd06490.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0063_nsd06515.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0064_nsd06522.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0065_nsd06525.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0066_nsd06559.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0067_nsd06641.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0068_nsd06714.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0070_nsd07008.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0071_nsd07040.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0072_nsd07121.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0073_nsd07208.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0074_nsd07337.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0075_nsd07367.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0076_nsd07410.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0078_nsd07481.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0079_nsd07655.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0080_nsd07660.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0081_nsd07841.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0083_nsd07945.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0087_nsd08110.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0088_nsd08205.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0089_nsd08226.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0090_nsd08263.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0091_nsd08275.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0092_nsd08319.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0094_nsd08395.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0095_nsd08416.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0096_nsd08436.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0097_nsd08466.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0098_nsd08510.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0099_nsd08632.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0100_nsd08647.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0101_nsd08808.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0102_nsd08844.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0103_nsd08926.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0104_nsd08934.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0105_nsd09028.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0107_nsd09148.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0108_nsd09231.png',
# ...
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0795_nsd57479.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0796_nsd57543.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0798_nsd57649.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0799_nsd57651.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0800_nsd57682.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0801_nsd57823.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0802_nsd57839.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0803_nsd57907.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0804_nsd58097.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0805_nsd58145.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0806_nsd58165.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0807_nsd58188.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0808_nsd58405.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0809_nsd58669.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0811_nsd59024.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0814_nsd59080.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0815_nsd59092.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0816_nsd59195.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0817_nsd59285.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0819_nsd59421.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0821_nsd59596.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0823_nsd59700.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0824_nsd59818.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0828_nsd60187.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0829_nsd60252.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0830_nsd60306.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0831_nsd60457.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0832_nsd60506.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0833_nsd60520.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0834_nsd60554.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0835_nsd60726.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0836_nsd60835.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0838_nsd60868.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0839_nsd60979.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0840_nsd61123.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0841_nsd61134.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0842_nsd61178.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0843_nsd61217.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0844_nsd61511.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0845_nsd61514.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0846_nsd61678.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0847_nsd61739.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0848_nsd61749.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0850_nsd61798.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0852_nsd61810.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0853_nsd61874.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0854_nsd61973.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0855_nsd62007.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0857_nsd62210.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0859_nsd62276.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0860_nsd62303.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0862_nsd62480.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0863_nsd62545.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0864_nsd62562.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0865_nsd62684.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0867_nsd62961.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0868_nsd63082.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0869_nsd63183.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0870_nsd63346.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0871_nsd63450.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0872_nsd63747.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0875_nsd63923.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0876_nsd63932.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0877_nsd63945.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0878_nsd64005.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0879_nsd64097.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0880_nsd64296.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0881_nsd64484.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0882_nsd64499.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0883_nsd64616.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0884_nsd64622.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0885_nsd64688.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0886_nsd64772.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0887_nsd64868.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0888_nsd64881.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0889_nsd64894.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0890_nsd64980.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0891_nsd65011.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0892_nsd65070.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0894_nsd65188.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0895_nsd65233.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0896_nsd65254.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0897_nsd65268.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0899_nsd65415.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0900_nsd65446.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0901_nsd65640.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0902_nsd65655.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0903_nsd65687.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0904_nsd65770.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0905_nsd65800.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0907_nsd65873.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0908_nsd65921.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0911_nsd66215.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0913_nsd66279.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0914_nsd66331.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0915_nsd66343.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0916_nsd66422.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0917_nsd66465.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0918_nsd66480.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0919_nsd66490.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0920_nsd66581.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0921_nsd66644.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0922_nsd66774.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0924_nsd66947.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0930_nsd67238.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0932_nsd67296.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0934_nsd67743.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0936_nsd67830.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0937_nsd68024.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0938_nsd68169.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0939_nsd68279.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0940_nsd68312.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0941_nsd68340.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0942_nsd68419.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0944_nsd68742.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0945_nsd68815.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0946_nsd68843.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0947_nsd68859.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0948_nsd68898.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0950_nsd69026.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0951_nsd69031.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0953_nsd69215.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0954_nsd69241.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0955_nsd69443.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0956_nsd69503.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0957_nsd69615.png',
#   '/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation/shared1000/shared0958_nsd69617.png',
#   ...]}

# %%
dataroot = r"/n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/Projects/VVS_Accentuation"
stimroot = join(dataroot, "shared1000")
data_path = join(dataroot, "vvs-accentuate-day1_normalize_paul_241119-241122.h5")
subject_id = 'paul_20241119-20241122'
batch_size = 96 
device = "cuda" 
reliability_thresh = -1
data_dict = load_neural_data(data_path, subject_id, stimroot)
image_fps = data_dict['image_fps']
resp_mat = data_dict['resp_mat']
reliability = data_dict['reliability']
ncsnr = data_dict['ncsnr']
figdir = join(dataroot, "model_outputs", subject_id, )
os.makedirs(figdir, exist_ok=True)
idx_train, idx_test = train_test_split(
    np.arange(len(resp_mat)), test_size=0.2, random_state=42, shuffle=True
)
# raise ValueError("stop here")
for modelname in ["resnet50_robust", "resnet50", ]: # "resnet50_clip", "resnet50_dino", 
    model, transforms_pipeline = load_model_transform(modelname, device=device)
    # Load data
    # Prepare dataset
    dataset = ImagePathDataset(image_fps, scores=resp_mat, transform=transforms_pipeline)

    fetcher = featureFetcher(model, input_size=(3, 224, 224), print_module=False)
    module_names = [name for name in fetcher.module_names.values() if "Bottleneck" in name and ("layer4" in name )] # or "layer3" in name
    print(module_names)
    for name in module_names: 
        fetcher.record(name, store_device='cpu', ingraph=False, )
    feat_dict_lyrswp = record_features(model, fetcher, dataset, batch_size=batch_size, device=device)
    fetcher.cleanup()

    thresh = reliability_thresh
    chan_mask = reliability > thresh
    resp_mat_sel = resp_mat[:, chan_mask]
    print(f"Fitting models for reliable channels > {thresh} N={chan_mask.sum()}")
    result_df_lyrswp_RidgeCV, fit_models_lyrswp_RidgeCV, Xdict_lyrswp_RidgeCV, Xtfmer_lyrswp_RidgeCV = perform_regression_sweeplayer_RidgeCV(feat_dict_lyrswp, resp_mat_sel, 
                                                                            layer_names=module_names, dimred_list=["srp", "pca1000"], 
                                                                        alpha_list=[1E-4, 1E-3, 1E-2, 1E-1, 1, 10, 100, 1E3, 1E4, 1E5, 1E6, 1E7, 1E8, 1E9],
                                                                        verbose=True)
    result_df_lyrswp_RidgeCV.to_csv(join(figdir, f"{subject_id}_{modelname}_sweep_regressors_highreliab_layers_sweep_RidgeCV.csv"))
    th.save(fit_models_lyrswp_RidgeCV, join(figdir, f"{subject_id}_{modelname}_sweep_regressors_highreliab_layers_fitmodels_RidgeCV.pth")) 
    th.save(Xtfmer_lyrswp_RidgeCV, join(figdir, f"{subject_id}_{modelname}_sweep_regressors_highreliab_layers_Xtfmer_RidgeCV.pkl"))
    # for half the layers (later half) ~ 20 mins
    result_df_lyrswp_formatted = result_df_lyrswp_RidgeCV.reset_index()
    result_df_lyrswp_formatted.rename(columns={"level_0": "layer_dimred", "level_1": "regressor", }, inplace=True)
    result_df_lyrswp_formatted["layer"] = result_df_lyrswp_formatted["layer_dimred"].apply(lambda x: x.split("_")[0])
    result_df_lyrswp_formatted["dimred"] = result_df_lyrswp_formatted["layer_dimred"].apply(lambda x: x.split("_")[-1])
    result_df_lyrswp_formatted.to_csv(join(figdir, f"{subject_id}_{modelname}_sweep_regressors_highreliab_layers_sweep_RidgeCV_formatted.csv"))


    figh, axs = plt.subplots(1, 2, figsize=(10, 5))
    plt.sca(axs[0])
    sns.lineplot(data=result_df_lyrswp_formatted, x="layer", 
            y="train_score", style="regressor", hue="dimred", ax=axs[0], marker="o")
    plt.xticks(rotation=45)
    xticklabels = plt.gca().get_xticklabels()
    xticklabels = [label.get_text().replace("Bottleneck", "B").replace(".layer", "L") for label in xticklabels]
    plt.xticks(ticks=range(len(xticklabels)), labels=xticklabels, rotation=45)
    plt.title("Training R2")

    plt.sca(axs[1])
    sns.lineplot(data=result_df_lyrswp_formatted, x="layer", 
            y="test_score", style="regressor", hue="dimred", ax=axs[1], marker="o")
    plt.xticks(rotation=45)
    xticklabels = plt.gca().get_xticklabels()
    xticklabels = [label.get_text().replace("Bottleneck", "B").replace(".layer", "L") for label in xticklabels]
    plt.xticks(ticks=range(len(xticklabels)), labels=xticklabels, rotation=45)
    plt.title("Test R2")

    plt.tight_layout()
    plt.suptitle(f"{subject_id} {modelname} layer sweep")
    saveallforms(figdir, f"{subject_id}_{modelname}_layer_sweep_GridCV_synopisis")
    plt.show()
# Out:
# Using cache found in /n/holylfs06/LABS/kempner_fellow_binxuwang/Users/binxuwang/torch_cache/hub/facebookresearch_dino_main
# /n/home12/binxuwang/.conda/envs/torch2/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /n/home12/binxuwang/.conda/envs/torch2/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# The (227, 227) setting is overwritten by the size in custom transform
# ['.layer4.Bottleneck0', '.layer4.Bottleneck1', '.layer4.Bottleneck2']
#   0%|          | 0/11 [00:00<?, ?it/s]
# .layer4.Bottleneck0 torch.Size([1028, 2048, 7, 7])
# .layer4.Bottleneck1 torch.Size([1028, 2048, 7, 7])
# .layer4.Bottleneck2 torch.Size([1028, 2048, 7, 7])
# FeatureFetcher hooks all freed
# Fitting models for reliable channels > -1 N=64
# .layer4.Bottleneck0 torch.Size([1028, 2048, 7, 7])
# .layer4.Bottleneck1 torch.Size([1028, 2048, 7, 7])
# .layer4.Bottleneck2 torch.Size([1028, 2048, 7, 7])
# .layer4.Bottleneck0_srp RidgeCV D2_train: 0.323 D2_test: 0.075
# .layer4.Bottleneck0_pca1000 RidgeCV D2_train: 0.398 D2_test: 0.082
# .layer4.Bottleneck1_srp RidgeCV D2_train: 0.352 D2_test: 0.069
# .layer4.Bottleneck1_pca1000 RidgeCV D2_train: 0.415 D2_test: 0.081
# .layer4.Bottleneck2_srp RidgeCV D2_train: 0.339 D2_test: 0.062
# .layer4.Bottleneck2_pca1000 RidgeCV D2_train: 0.414 D2_test: 0.075
#                                                                                  alpha  \
# .layer4.Bottleneck0_srp     RidgeCV  [100000.0, 100000.0, 10000000.0, 100000.0, 100...
# .layer4.Bottleneck0_pca1000 RidgeCV  [10000.0, 10000.0, 1000000.0, 10000.0, 100000....
# .layer4.Bottleneck1_srp     RidgeCV  [10000.0, 10000.0, 1000000000.0, 10000.0, 1000...
# .layer4.Bottleneck1_pca1000 RidgeCV  [10000.0, 10000.0, 1000000.0, 10000.0, 100000....
# .layer4.Bottleneck2_srp     RidgeCV  [10000.0, 10000.0, 10000000.0, 10000.0, 100000...
# .layer4.Bottleneck2_pca1000 RidgeCV  [10000.0, 10000.0, 1000000.0, 10000.0, 100000....
#
#                                     train_score test_score n_feat
# .layer4.Bottleneck0_srp     RidgeCV     0.32278   0.075459   5944
# .layer4.Bottleneck0_pca1000 RidgeCV    0.398457   0.081685   1000
# .layer4.Bottleneck1_srp     RidgeCV    0.351957   0.068622   5944
# .layer4.Bottleneck1_pca1000 RidgeCV    0.415258   0.080964   1000
# .layer4.Bottleneck2_srp     RidgeCV    0.339143   0.062043   5944
# .layer4.Bottleneck2_pca1000 RidgeCV    0.413689   0.074953   1000
